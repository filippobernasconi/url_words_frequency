# %%
from selenium import webdriver
# this is tested on Firefox or you can use "webdriver.Chrome()"
driver = webdriver.Chrome("webdriver/chromedriver")
#webdriver = "/Users/filip/OneDrive/Desktop/python/url_words_frequency/webdriver/chromedriver"
#browser = webdriver.Chromedriver()
driver.get("https://www.facebook.com/")

# %%
websites_list = [
    "https://contioutra.com",
    "https://savonanews.it",
    "http://switchfan.org",
"http://contioutra.com",
"http://ricordinvaligia.it",
"http://sportlegnano.it",
"http://geek-vintage.com",
"http://fiorentinanews.com",
"http://infocilento.it",
"http://garotasquecurtemanimes.com.br",
"http://bimbieviaggi.it",
"http://altarimini.it",
"http://puretravel.com",
"http://reisebuch.de",
"http://trivenetogoal.it",
"http://trivenetogoal.it",
"http://louiseethelene.de",
"http://gudtechtricks.com",
"http://ilcaudino.it",
"http://travelfashiontips.com",
"http://siniscolanotizie.net",
"http://dottorsport.info",
"http://salentosport.net",
"http://salentosport.net",
"http://techniblogic.com",
"http://fiorentinanews.com",
"http://hallo-frau.de",
"http://newsmondo.it",
"http://elclarinweb.com",
"http://giornaledipuglia.com",
"http://informapuglia.com",
"http://helpconsumatori.it",
"http://bioecogeo.com",
"http://romait.it",
"http://ilquotidianodellazio.it",
"http://travelnostop.com",
"http://sicurmoto.it",
"http://segundoenfoque.com",
"http://risparmioeinvestimento.it",
"http://travelfashiontips.com",
]

# %%
driver = webdriver.Chrome("webdriver/chromedriver")
driver.get("http://helpconsumatori.it")
html_source = driver.page_source
print(html_source)
# Out:
# <html lang="it-IT" style="transform: none;"><head>
#     <meta charset="UTF-8">
#     <meta name="viewport" content="width=device-width, initial-scale=1">
#     <link rel="profile" href="http://gmpg.org/xfn/11">
#
#
#     		<style type="text/css">
# 		</style>
# 		<!-- Jetpack Site Verification Tags -->
# <meta name="google-site-verification" content="wjZxBE3_D8v-Ktcmxp2vCd0NI6ephHtsOu_WxZiG6uQ">
#
# 	<!-- This site is optimized with the Yoast SEO plugin v14.1 - https://yoast.com/wordpress/plugins/seo/ -->
# 	<title>Help Consumatori | L'informazione per i cittadini responsabili</title>
# 	<meta name="description" content="Help Consumatori è la prima e unica agenzia quotidiana d’informazione sui diritti dei cittadini-consumatori e sull’associazionismo che li tutela">
# 	<meta name="robots" content="index, follow">
# 	<meta name="googlebot" content="index, follow, max-snippet:-1, max-image-preview:large, max-video-preview:-1">
# ...
