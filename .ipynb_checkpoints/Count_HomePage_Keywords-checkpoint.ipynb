# %%
#todo
#prendere valori solo quando "vuoto"
#underscore e backslash non funzionanti
#reset index

# %%
import pandas as pd
from stop_words import get_stop_words
import re
from selenium import webdriver
import time

# %%
#driver = webdriver.Chrome("webdriver/chromedriver")

# %%
#stopwords base importate

stop_words = get_stop_words('it')
stop_words += get_stop_words('en')
stop_words += get_stop_words('pt')
stop_words += get_stop_words('es')
stop_words += get_stop_words('de')
stop_words += get_stop_words('fr')

# %%
#stopwords personali aggiunte da me

stop_words += ["priority","target","events","eventname","flavors","callback","document","stato","legacy","window","visualizza"]
stop_words += ["module","article","cette","encore","faire","d’une"]
stop_words += ["c'est","della","delle"]
stop_words += ["settembre",	"positivi",	"giorno",	"giorni",	"agosto",	"settimana",	"progetto",	"weeks",	"evidenza",	"siniscola",	"della",	"lucia",	"santa"]

# %%
df = pd.read_excel("sites_to_check.xlsx")

# %%
#sites_to_check_df
df
# Out:
#                          site                    url_to_import  \
# 0               switchfan.org                    switchfan.org
# 1              contioutra.com                   contioutra.com
# 2          ricordinvaligia.it               ricordinvaligia.it
# 3             sportlegnano.it                  sportlegnano.it
# 4            geek-vintage.com                 geek-vintage.com
# ..                        ...                              ...
# 290            mentalitch.com            http://mentalitch.com
# 291         mammarisparmio.it         http://mammarisparmio.it
# 292  raushier-reisemagazin.de  http://raushier-reisemagazin.de
# 293           lanotiziaweb.it           http://lanotiziaweb.it
# 294   lifestylemadeinitaly.it   http://lifestylemadeinitaly.it
#
#                                                  esito
# 0    [['switch', 35], ['nintendo', 31], ['notre', 1...
# 1    [['outra', 15], ['conti', 9], ['filmes', 6], [...
# 2    [['della', 12], ['settembre', 8], ['agosto', 8...
# 3    [['legnano', 63], ['serie', 43], ['amministrat...
# 4    [['classé', 11], ['article', 6], ['vidéo', 5],...
# ..                                                 ...
# 290                                              vuoto
# 291                                              vuoto
# 292                                              vuoto
# 293                                              vuoto
# 294                                              vuoto
#
# [295 rows x 3 columns]

# %%
#spostare su file separato

def removeHtmlTags(lista):
    text = re.sub("\<(.*?)\>","",home_page_content)
    return text


def stripPunctuations(home_page_content):
    
    #bad_chars = "?.,;:!\'"
    bad_chars = ["\n","\t","?",".",",",";",":","!","\\","’"]
    for char in home_page_content:
        if char in bad_chars:
            home_page_content = home_page_content.replace(char,"")
        
    return home_page_content
        


def avoidStopWords(wordlist, stop_words):
    for word in wordlist:
        if word not in stop_words:
            print(word)
            list_saved_words.append(word)
    return list_saved_words


def removeWordsWithBadChars(content):
    bad_list = ["/","(",")", "&", "{","’"]
    bad_list += ["}", "h1", "h2", "h3",]
    bad_list += ["px","_","\\","&","@", "#","-","%","'"]
    bad_list += ["1","2","3","4","5","6","7","8","9","0"]
    print(bad_list)
    for bad_char in bad_list:
        for word in content:
            if bad_char in word:
                content.remove(word)
    return content


def CountFrequency(list_saved_words): 
    lista_2 = []
    
    for item in list_saved_words:
        local_list = [item, list_saved_words.count(item)]
        lista_2.append(local_list)
    
    return lista_2


def removeDuplicates(list_saved_words):
    unique_keywords = []
    for item in list_saved_words:
        if item not in unique_keywords:
            unique_keywords.append(item)
    return unique_keywords



def sortList(sub_li): 
  
    # key is set to sort using second element of  
    # sublist lambda has been used 
    sub_li.sort(reverse=True, key = lambda x: x[1]) 
    return sub_li

# %%
home_page_content = ""
temp_keyword_frequencies = [] #serve per eliminare delle stop-words extra
frequency_dict = {}
index = 0
all_words = [] #serve per eliminare delle stop-words extra, superato

for url in df["url_to_import"]:
    print(url)
    if "http://" not in url: #togliendo l'http dal df e poi dal file excel rendo visibile che l'url è già stato controllato
        print("nisba")
        index+=1
        continue
    else:
        driver = webdriver.Chrome("webdriver/chromedriver")
        home_page_content_saved = []
        driver.get(url)
        print("url preso")
        time.sleep(5) #non sono sicuro che sia necessario, il mio timore è che certe pagine non carichino per intero (numero parole sempre diverso)
        home_page_content = driver.find_element_by_tag_name('body').text
        home_page_content = str(home_page_content)
        home_page_content = home_page_content.lower()
        home_page_content = removeHtmlTags(home_page_content)
        home_page_content = stripPunctuations(home_page_content)
        home_page_content = home_page_content.split(" ")
        #home_page_content diventa lista


        for word in home_page_content:
            if len(word)> 4 and len(word)< 20: 
                home_page_content_saved.append(word)
                home_page_content = home_page_content_saved

        #togliamo parole con bad_char
        home_page_content = removeWordsWithBadChars(home_page_content)
        all_words += home_page_content
        print("all_words sono:")
        print(len(all_words))

        #calcoliamo la frequenza, ma siamo sempre in una lista
        home_page_content = CountFrequency(home_page_content)

        #togliamo le keyword che sono state usate una volta sola
        temp_keyword_frequencies = []
        
        for item in home_page_content:
            if item[1] >= 2:
                temp_keyword_frequencies.append(item)
            home_page_content = temp_keyword_frequencies
         
        #sistemino per eliminare un po' di cripto-stopwords
        frequent_keywords = []
        
        for item in home_page_content:
            if item[1] >= 4:
                frequent_keywords.append(item)
        #print(frequent_keywords)
    
        print(home_page_content)

        #togliamo i duplicati
        home_page_content = removeDuplicates(home_page_content)
        #print(home_page_content)   

        #ordiniamo
        home_page_content = sortList(home_page_content)
        print("lunghezza finale")
        print(len(home_page_content))
        home_page_content = str(home_page_content) #prima di inserire i valori sul foglio excel trasformiamo in stringa

        df["esito"][index] = home_page_content
        df["url_to_import"][index] = df["url_to_import"][index].replace("http://","")
        index += 1
        driver.close()

        #finalmente si trasforma tutto in dizionario
        #il dizionario ha come key il sito, come value il mega-listone di keyword+frequency     
        #frequency_dict[url] = home_page_content



#si ricomincia da capo con un nuovo sito
    

    
#print(frequency_dict)
# Out:
# switchfan.org
# nisba
# contioutra.com
# nisba
# ricordinvaligia.it
# nisba
# sportlegnano.it
# nisba
# geek-vintage.com
# nisba
# fiorentinanews.com
# nisba
# infocilento.it
# nisba
# garotasquecurtemanimes.com.br
# nisba
# bimbieviaggi.it
# nisba
# altarimini.it
# nisba
# puretravel.com
# nisba
# reisebuch.de
# nisba
# http://trivenetogoal.it
# url preso
# ['/', '(', ')', '&', '{', '’', '}', 'h1', 'h2', 'h3', 'px', '_', '\\', '&', '@', '#', '-', '%', "'", '1', '2', '3', '4', '5', '6', '7', '8', '9', '0']
# all_words sono:
# 30
# [['qualsiasi', 2], ['qualsiasi', 2]]
# lunghezza finale
# 1
# http://louiseethelene.de
# url preso
# ['/', '(', ')', '&', '{', '’', '}', 'h1', 'h2', 'h3', 'px', '_', '\\', '&', '@', '#', '-', '%', "'", '1', '2', '3', '4', '5', '6', '7', '8', '9', '0']
# all_words sono:
# 58
# [['tipps', 2], ['tipps', 2]]
# lunghezza finale
# 1
# gudtechtricks.com
# nisba
# http://ilcaudino.it
# url preso
# ['/', '(', ')', '&', '{', '’', '}', 'h1', 'h2', 'h3', 'px', '_', '\\', '&', '@', '#', '-', '%', "'", '1', '2', '3', '4', '5', '6', '7', '8', '9', '0']
# all_words sono:
# 388
# [['settembre', 6], ['della', 2], ['rassegna', 15], ['stampa', 14], ['sabato', 2], ['settembre', 6], ['ospedale', 2], ['nuovi', 2], ['positivi', 6], ['provincia', 3], ['giorno', 13], ['rassegna', 15], ['stampa', 14], ['venerdì', 2], ['settembre', 6], ['giorni', 18], ['giorni', 18], ['rassegna', 15], ['stampa', 14], ['giovedì', 2], ['settembre', 6], ['della', 2], ['giorno', 13], ['cervinara', 2], ['scuola', 3], ['giorni', 18], ['positivi', 6], ['giorno', 13], ['giorni', 18], ['giorni', 18], ['giorni', 18], ['scuola', 3], ['giorni', 18], ['rassegna', 15], ['stampa', 14], ['mercoledì', 2], ['settembre', 6], ['giorni', 18], ['facaterina', 2], ['giorni', 18], ['giorni', 18], ['rassegna', 15], ['stampa', 14], ['martedì', 3], ['settembre', 6], ['giorni', 18], ['rassegna', 15], ['stampa', 14], ['lunedì', 2], ['agosto', 8], ['giorni', 18], ['rassegna', 15], ['stampa', 14], ['agosto', 8], ['settimana', 7], ['rassegna', 15], ['stampa', 14], ['sabato', 2], ['agosto', 8], ['settimana', 7], ['settimana', 7], ['rassegna', 15], ['stampa', 14], ['venerdì', 2], ['agosto', 8], ['giorni', 18], ['giorni', 18], ['giorno', 13], ['scuola', 3], ['settimana', 7], ['settimana', 7], ['rassegna', 15], ['stampa', 14], ['giovedì', 2], ['agosto', 8], ['ospedale', 2], ['positivi', 6], ['giorno', 13], ['giorno', 13], ['giorno', 13], ['giorno', 13], ['facaterina', 2], ['giorni', 18], ['martedì', 3], ['giorno', 13], ['giorno', 13], ['nuovi', 2], ['positivi', 6], ['giorno', 13], ['coronavirus', 2], ['giorno', 13], ['settimana', 7], ['farassegna', 3], ['stampala', 3], ['rassegna', 15], ['stampa', 14], ['mercoledì', 2], ['agosto', 8], ['settimane', 2], ['farassegna', 3], ['stampala', 3], ['rassegna', 15], ['stampa', 14], ['martedì', 3], ['agosto', 8], ['faedicolavalle', 2], ['caudina', 2], ['quotidiani', 2], ['edicola', 2], ['ampia', 2], ['rassegna', 15], ['giorno', 13], ['giorni', 18], ['giorni', 18], ['coronavirus', 2], ['provincia', 3], ['giorni', 18], ['positivi', 6], ['positivi', 6], ['provincia', 3], ['settimane', 2], ['farassegna', 3], ['stampala', 3], ['rassegna', 15], ['stampa', 14], ['lunedì', 2], ['agosto', 8], ['faedicolavalle', 2], ['caudina', 2], ['quotidiani', 2], ['edicola', 2], ['ampia', 2], ['rassegna', 15], ['settimana', 7], ['stampa', 14], ['cervinara', 2], ['smart', 3], ['ecommerce', 3], ['smart', 3], ['ecommerce', 3], ['curatore', 2], ['smart', 3], ['ecommerce', 3], ['curatore', 2]]
# lunghezza finale
# 33
# http://travelfashiontips.com
# url preso
# ['/', '(', ')', '&', '{', '’', '}', 'h1', 'h2', 'h3', 'px', '_', '\\', '&', '@', '#', '-', '%', "'", '1', '2', '3', '4', '5', '6', '7', '8', '9', '0']
# all_words sono:
# 675
# [['travelil', 2], ['progetto', 4], ['oikos', 2], ['comunità', 3], ['maasai', 3], ['mkuru', 3], ['borghi', 2], ['travelil', 2], ['progetto', 4], ['oikos', 2], ['comunità', 3], ['maasai', 3], ['mkuru', 3], ['vedere', 3], ['messicodinydia', 2], ['migliori', 2], ['messicodinydia', 2], ['agrigento', 2], ['vedere', 3], ['migliori', 2], ['messico', 2], ['dormire', 3], ['estate', 3], ['costa', 2], ['vedere', 3], ['costa', 2], ['mangiare', 3], ['piatti', 2], ['piatti', 2], ['dormire', 3], ['napoli', 3], ['estate', 3], ['dormire', 3], ['valigia', 4], ['mettere', 2], ['valigia', 4], ['viaggio', 6], ['mettere', 2], ['portare', 2], ['viaggio', 6], ['regalo', 2], ['portare', 2], ['camper', 2], ['agrigento', 2], ['camper', 2], ['progetto', 4], ['social', 2], ['media', 2], ['progetto', 4], ['comunità', 3], ['maasai', 3], ['mkuru', 3], ['2020gen', 2], ['2020gen', 2], ['anche', 2], ['weeks', 4], ['viaggio', 6], ['weeks', 4], ['weeks', 4], ['napoli', 3], ['weeks', 4], ['social', 2], ['media', 2], ['borghi', 2], ['consigli', 2], ['consigli', 2], ['viaggio', 6], ['mangiare', 3], ['viaggio', 6], ['mangiare', 3], ['estate', 3], ['regalo', 2], ['napoli', 3], ['valigia', 4], ['messico', 2], ['milano', 2], ['milano', 2], ['valigia', 4], ['vacanze', 2], ['vacanze', 2], ['viaggi', 3], ['viaggi', 3], ['viaggi', 3], ['anche', 2], ['viaggio', 6]]
# lunghezza finale
# 33
# http://siniscolanotizie.net
# url preso
# ['/', '(', ')', '&', '{', '’', '}', 'h1', 'h2', 'h3', 'px', '_', '\\', '&', '@', '#', '-', '%', "'", '1', '2', '3', '4', '5', '6', '7', '8', '9', '0']
# all_words sono:
# 1065
# [['network', 2], ['notizie', 3], ['nostro', 2], ['evidenza', 5], ['positività', 2], ['siniscola', 5], ['evidenza', 5], ['evidenza', 5], ['nostro', 2], ['evidenza', 5], ['evidenza', 5], ['spazio', 2], ['della', 8], ['notizie', 3], ['lucia', 4], ['siniscola', 5], ['tecnico', 2], ['della', 8], ['redazione', 6], ['santa', 5], ['lucia', 4], ['della', 8], ['redazione', 6], ['santa', 5], ['lucia', 4], ['della', 8], ['redazione', 6], ['della', 8], ['redazione', 6], ['santa', 5], ['della', 8], ['redazione', 6], ['libro', 2], ['della', 8], ['redazione', 6], ['coronas', 2], ['siniscola', 5], ['notizie', 3], ['barbagia', 3], ['barbagia', 3], ['gavoi', 2], ['barbagia', 3], ['gavoi', 2], ['gonone', 3], ['sardegna', 2], ['gonone', 3], ['sardegna', 2], ['gonone', 3], ['libro', 2], ['marghine', 3], ['coronas', 2], ['marghine', 3], ['marghine', 3], ['positività', 2], ['network', 2], ['tutti', 2], ['santa', 5], ['tutti', 2], ['della', 8], ['tecnico', 2], ['santa', 5], ['lucia', 4], ['siniscola', 5], ['siniscola', 5], ['polisportiva', 2], ['montalbo', 2], ['montalbo', 2], ['polisportiva', 2], ['spazio', 2]]
# lunghezza finale
# 22
# http://dottorsport.info
# url preso
# ['/', '(', ')', '&', '{', '’', '}', 'h1', 'h2', 'h3', 'px', '_', '\\', '&', '@', '#', '-', '%', "'", '1', '2', '3', '4', '5', '6', '7', '8', '9', '0']
# all_words sono:
# 1206
# [['dottor', 2], ['virtù', 3], ['legumi', 3], ['trucchi', 4], ['consigli', 3], ['sfruttare', 3], ['meglio', 3], ['trucchi', 4], ['grasso', 2], ['grasso', 2], ['alcool', 2], ['alcool', 2], ['deposito', 2], ['germi', 2], ['batteri', 2], ['nostrale', 2], ['virtù', 3], ['legumi', 3], ['trucchi', 4], ['consigli', 3], ['sfruttare', 3], ['meglio', 3], ['qualitàmangiare', 2], ['grassi…', 2], ['deposito', 2], ['germi', 2], ['batteri', 2], ['nostrale', 2], ['virtù', 3], ['legumi', 3], ['trucchi', 4], ['consigli', 3], ['sfruttare', 3], ['meglio', 3], ['qualitàmangiare', 2], ['grassi…', 2], ['dottor', 2]]
# lunghezza finale
# 15
# http://salentosport.net
# url preso
# ['/', '(', ')', '&', '{', '’', '}', 'h1', 'h2', 'h3', 'px', '_', '\\', '&', '@', '#', '-', '%', "'", '1', '2', '3', '4', '5', '6', '7', '8', '9', '0']
# all_words sono:
# 1641
# [['primo', 4], ['turno', 3], ['eliminatorio', 3], ['anche', 5], ['primo', 4], ['turno', 3], ['eliminatorio', 3], ['anche', 5], ['salentosport', 4], ['eccellenza', 2], ['promozione', 3], ['gironi', 2], ['stagione', 4], ['sentenza', 2], ['cambia', 2], ['anche', 5], ['mercato', 8], ['punto', 4], ['sulle', 2], ['talentino', 3], ['norvegese', 3], ['taccuino', 4], ['giallorossi', 3], ['arrivo', 4], ['nuove', 3], ['ribaltone', 2], ['tricase', 2], ['fiamma', 2], ['jonica', 2], ['batte', 2], ['colpi', 2], ['punto', 4], ['talentino', 3], ['norvegese', 3], ['taccuino', 4], ['giallorossi', 3], ['arrivo', 4], ['nuove', 3], ['salentosport', 4], ['listkowski', 2], ['lecce', 4], ['altro', 2], ['colpo', 2], ['taccuino', 4], ['scelti', 2], ['della', 3], ['pubblicazione', 2], ['calendari', 2], ['salentosport', 4], ['settembre', 12], ['stagione', 4], ['serie', 5], ['partenza', 2], ['campionati', 3], ['dalla', 3], ['serie', 5], ['seconda', 2], ['salentosport', 4], ['campionati', 3], ['serie', 5], ['primo', 4], ['turno', 3], ['eliminatorio', 3], ['anche', 5], ['eccellenza', 2], ['promozione', 3], ['gironi', 2], ['stagione', 4], ['women', 2], ['primo', 4], ['ufficiale', 3], ['mercato', 8], ['altro', 2], ['arrivo', 4], ['lecce', 4], ['nuovo', 2], ['sentenza', 2], ['cambia', 2], ['anche', 5], ['mercato', 8], ['punto', 4], ['sulle', 2], ['talentino', 3], ['norvegese', 3], ['taccuino', 4], ['giallorossi', 3], ['arrivo', 4], ['nuove', 3], ['colpo', 2], ['scelti', 2], ['della', 3], ['pubblicazione', 2], ['calendari', 2], ['ribaltone', 2], ['tricase', 2], ['fiamma', 2], ['jonica', 2], ['batte', 2], ['colpi', 2], ['punto', 4], ['mercato', 8], ['lecce', 4], ['women', 2], ['nuovo', 2], ['arriva', 3], ['ancora', 2], ['lascia', 2], ['mercato', 8], ['partenza', 2], ['campionati', 3], ['dalla', 3], ['serie', 5], ['seconda', 2], ['nardò', 2], ['arriva', 3], ['dalla', 3], ['ufficiale', 3], ['stagione', 4], ['ritiro', 3], ['promozione', 3], ['ritiro', 3], ['quadro', 2], ['mercato', 8], ['girone', 2], ['squadra', 4], ['squadra', 4], ['listkowski', 2], ['lascia', 2], ['ritiro', 3], ['nardò', 2], ['lecce', 4], ['serie', 5], ['ancora', 2], ['ufficiale', 3], ['della', 3], ['quadro', 2], ['mercato', 8], ['girone', 2], ['squadra', 4], ['squadra', 4], ['mercato', 8], ['arriva', 3], ['settembre', 12], ['agosto', 11], ['luglio', 10], ['giugno', 10], ['maggio', 10], ['aprile', 10], ['marzo', 10], ['febbraio', 10], ['gennaio', 10], ['dicembre', 10], ['novembre', 10], ['ottobre', 10], ['settembre', 12], ['agosto', 11], ['luglio', 10], ['giugno', 10], ['maggio', 10], ['aprile', 10], ['marzo', 10], ['febbraio', 10], ['gennaio', 10], ['dicembre', 10], ['novembre', 10], ['ottobre', 10], ['settembre', 12], ['agosto', 11], ['luglio', 10], ['giugno', 10], ['maggio', 10], ['aprile', 10], ['marzo', 10], ['febbraio', 10], ['gennaio', 10], ['dicembre', 10], ['novembre', 10], ['ottobre', 10], ['settembre', 12], ['agosto', 11], ['luglio', 10], ['giugno', 10], ['maggio', 10], ['aprile', 10], ['marzo', 10], ['febbraio', 10], ['gennaio', 10], ['dicembre', 10], ['novembre', 10], ['ottobre', 10], ['settembre', 12], ['agosto', 11], ['luglio', 10], ['giugno', 10], ['maggio', 10], ['aprile', 10], ['marzo', 10], ['febbraio', 10], ['gennaio', 10], ['dicembre', 10], ['novembre', 10], ['ottobre', 10], ['settembre', 12], ['agosto', 11], ['luglio', 10], ['giugno', 10], ['maggio', 10], ['aprile', 10], ['marzo', 10], ['febbraio', 10], ['gennaio', 10], ['dicembre', 10], ['novembre', 10], ['ottobre', 10], ['settembre', 12], ['agosto', 11], ['luglio', 10], ['giugno', 10], ['maggio', 10], ['aprile', 10], ['marzo', 10], ['febbraio', 10], ['gennaio', 10], ['dicembre', 10], ['novembre', 10], ['ottobre', 10], ['settembre', 12], ['agosto', 11], ['luglio', 10], ['giugno', 10], ['maggio', 10], ['aprile', 10], ['marzo', 10], ['febbraio', 10], ['gennaio', 10], ['dicembre', 10], ['novembre', 10], ['ottobre', 10], ['settembre', 12], ['agosto', 11], ['luglio', 10], ['giugno', 10], ['maggio', 10], ['aprile', 10], ['marzo',  ...
# lunghezza finale
# 62
# http://techniblogic.com
# url preso
# ['/', '(', ')', '&', '{', '’', '}', 'h1', 'h2', 'h3', 'px', '_', '\\', '&', '@', '#', '-', '%', "'", '1', '2', '3', '4', '5', '6', '7', '8', '9', '0']
# all_words sono:
# 1955
# [['music', 5], ['making', 3], ['android', 8], ['games', 4], ['mobile', 5], ['androidmodified', 2], ['mystery', 4], ['movies', 4], ['netflix', 3], ['india', 7], ['india', 7], ['tiktok', 3], ['android', 8], ['iphone', 3], ['review', 2], ['review', 2], ['online', 2], ['improved', 2], ['chain', 3], ['logisticsmodified', 2], ['raises', 2], ['crores', 2], ['bitkraft', 3], ['venturesmodified', 2], ['android', 8], ['iosmodified', 2], ['clear', 2], ['innovative', 2], ['evermodified', 2], ['clear', 2], ['innovative', 2], ['evermodified', 2], ['craft', 2], ['guilty', 2], ['repeating', 2], ['these', 4], ['quarantine', 3], ['these', 4], ['tipsmodified', 2], ['start', 2], ['improved', 2], ['chain', 3], ['logisticsmodified', 2], ['chain', 3], ['there', 2], ['things', 2], ['reliable', 2], ['digital', 2], ['search', 2], ['online', 2], ['reliable', 2], ['digital', 2], ['games', 4], ['mobile', 5], ['androidmodified', 2], ['games', 4], ['mobile', 5], ['android', 8], ['information', 2], ['mystery', 4], ['movies', 4], ['netflix', 3], ['india', 7], ['mystery', 4], ['movies', 4], ['netflix', 3], ['india', 7], ['mystery', 4], ['movies', 4], ['india', 7], ['tiktok', 3], ['tiktok', 3], ['india', 7], ['search', 2], ['watch', 3], ['android', 8], ['iphone', 3], ['android', 8], ['iphone', 3], ['information', 2], ['music', 5], ['making', 3], ['android', 8], ['iosmodified', 2], ['music', 5], ['music', 5], ['water', 2], ['heater', 2], ['india', 7], ['water', 2], ['heater', 2], ['which', 2], ['craft', 2], ['guilty', 2], ['repeating', 2], ['these', 4], ['quarantine', 3], ['these', 4], ['tipsmodified', 2], ['quarantine', 3], ['start', 2], ['raises', 2], ['crores', 2], ['bitkraft', 3], ['venturesmodified', 2], ['bitkraft', 3], ['there', 2], ['games', 4], ['which', 2], ['music', 5], ['making', 3], ['android', 8], ['mobile', 5], ['things', 2], ['mobile', 5], ['wireless', 4], ['wireless', 4], ['charging', 4], ['station', 2], ['wireless', 4], ['charging', 4], ['compatible', 2], ['charging', 4], ['stand', 3], ['charging', 4], ['station', 2], ['charger', 2], ['stand', 3], ['apple', 2], ['watch', 3], ['wireless', 4], ['charger', 2], ['apple', 2], ['watch', 3], ['stand', 3], ['compatible', 2]]
# lunghezza finale
# 49
# http://hallo-frau.de
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-9-7ca20750d4e0> in <module>
#      14         driver = webdriver.Chrome("webdriver/chromedriver")
#      15         home_page_content_saved = []
# ---> 16         driver.get(url)
#      17         print("url preso")
#      18         time.sleep(5) #non sono sicuro che sia necessario, il mio timore è che certe pagine non carichino per intero (numero parole sempre diverso)
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in get(self, url)
#     331         Loads a web page in the current browser session.
#     332         """
# --> 333         self.execute(Command.GET, {'url': url})
#     334
#     335     @property
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in execute(self, driver_command, params)
#     317
#     318         params = self._wrap_value(params)
# --> 319         response = self.command_executor.execute(driver_command, params)
#     320         if response:
#     321             self.error_handler.check_response(response)
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\remote\remote_connection.py in execute(self, command, params)
#     372         data = utils.dump_json(params)
#     373         url = '%s%s' % (self._url, path)
# --> 374         return self._request(command_info[0], url, body=data)
#     375
#     376     def _request(self, method, url, body=None):
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\remote\remote_connection.py in _request(self, method, url, body)
#     395
#     396         if self.keep_alive:
# --> 397             resp = self._conn.request(method, url, body=body, headers=headers)
#     398
#     399             statuscode = resp.status
#
# ~\anaconda3\lib\site-packages\urllib3\request.py in request(self, method, url, fields, headers, **urlopen_kw)
#      77             )
#      78         else:
# ---> 79             return self.request_encode_body(
#      80                 method, url, fields=fields, headers=headers, **urlopen_kw
#      81             )
#
# ~\anaconda3\lib\site-packages\urllib3\request.py in request_encode_body(self, method, url, fields, headers, encode_multipart, multipart_boundary, **urlopen_kw)
#     169         extra_kw.update(urlopen_kw)
#     170
# --> 171         return self.urlopen(method, url, **extra_kw)
#
# ~\anaconda3\lib\site-packages\urllib3\poolmanager.py in urlopen(self, method, url, redirect, **kw)
#     334             response = conn.urlopen(method, url, **kw)
#     335         else:
# --> 336             response = conn.urlopen(method, u.request_uri, **kw)
#     337
#     338         redirect_location = redirect and response.get_redirect_location()
#
# ~\anaconda3\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     668
#     669             # Make the request on the httplib connection object.
# --> 670             httplib_response = self._make_request(
#     671                 conn,
#     672                 method,
#
# ~\anaconda3\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     424                     # Python 3 (including for exceptions like SystemExit).
#     425                     # Otherwise it looks like a bug in the code.
# --> 426                     six.raise_from(e, None)
#     427         except (SocketTimeout, BaseSSLError, SocketError) as e:
#     428             self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# ~\anaconda3\lib\site-packages\urllib3\packages\six.py in raise_from(value, from_value)
#
# ~\anaconda3\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     419                 # Python 3
#     420                 try:
# --> 421                     httplib_response = conn.getresponse()
#     422                 except BaseException as e:
#     423                     # Remove the TypeError from the exception chain in
#
# ~\anaconda3\lib\http\client.py in getresponse(self)
#    1330         try:
#    1331             try:
# -> 1332                 response.begin()
#    1333             except ConnectionError:
#    1334                 self.close()
#
# ~\anaconda3\lib\http\client.py in begin(self)
#     301         # read until we get a non-100 response
#     302         while True:
# --> 303             version, status, reason = self._read_status()
#     304             if status != CONTINUE:
#     305                 break
#
# ~\anaconda3\lib\http\client.py in _read_status(self)
#     262
#     263     def _read_status(self):
# --> 264         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     265         if len(line) > _MAXLINE:
#     266             raise LineTooLong("status line")
#
# ~\anaconda3\lib\socket.py in readinto(self, b)
#     667         while True:
#     668             try:
# --> 669                 return self._sock.recv_into(b)
#     670             except timeout:
#     671                 self._timeout_occurred = True
#
# KeyboardInterrupt:

# %%
df[10:30]
# Out:
#                        site                   url_to_import  \
# 10           puretravel.com                  puretravel.com
# 11             reisebuch.de                    reisebuch.de
# 12         trivenetogoal.it                trivenetogoal.it
# 13        louiseethelene.de               louiseethelene.de
# 14        gudtechtricks.com               gudtechtricks.com
# 15             ilcaudino.it                    ilcaudino.it
# 16    travelfashiontips.com           travelfashiontips.com
# 17     siniscolanotizie.net            siniscolanotizie.net
# 18         dottorsport.info                dottorsport.info
# 19         salentosport.net                salentosport.net
# 20         techniblogic.com                techniblogic.com
# 21            hallo-frau.de            http://hallo-frau.de
# 22             newsmondo.it             http://newsmondo.it
# 23          elclarinweb.com          http://elclarinweb.com
# 24     giornaledipuglia.com     http://giornaledipuglia.com
# 25        informapuglia.com        http://informapuglia.com
# 26       helpconsumatori.it       http://helpconsumatori.it
# 27            bioecogeo.com            http://bioecogeo.com
# 28                romait.it                http://romait.it
# 29  ilquotidianodellazio.it  http://ilquotidianodellazio.it
#
#                                                 esito
# 10  [['islands', 10], ['operators', 6], ['local', ...
# 11  [['jetzt', 4], ['anschauen', 4], ['bestellen',...
# 12                                 [['qualsiasi', 2]]
# 13                                     [['tipps', 2]]
# 14  [['…read', 10], ['development', 5], ['online',...
# 15  [['giorni', 18], ['rassegna', 15], ['stampa', ...
# 16  [['viaggio', 6], ['progetto', 4], ['valigia', ...
# 17  [['della', 8], ['redazione', 6], ['evidenza', ...
# 18  [['trucchi', 4], ['virtù', 3], ['legumi', 3], ...
# 19  [['settembre', 12], ['agosto', 11], ['luglio',...
# 20  [['android', 8], ['india', 7], ['music', 5], [...
# 21                                              vuoto
# 22                                              vuoto
# 23                                              vuoto
# 24                                              vuoto
# 25                                              vuoto
# 26                                              vuoto
# 27                                              vuoto
# 28                                              vuoto
# 29                                              vuoto

# %%
df.to_excel("sites_to_check.xlsx",index=False)

# %%
#df.to_excel("sites_to_check_sbagliato.xlsx",index=False)

# %%
#from pandas import DataFrame
df_all_words = DataFrame(all_words)
df_all_words
df_all_words.to_excel("ricerca_stopwords.xlsx")

# %%
#eliminare stopwords extra
from pandas import DataFrame
df_all_words = DataFrame(frequent_keywords)
df_all_words
df_all_words.to_excel("frequent_keywords.xlsx")
