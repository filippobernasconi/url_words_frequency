# %%
import pandas as pd

# %%
yes_words = ["fashion","lifestyle","moda","casino","studente","studia","casa","arredo","corso", "notizia","notizie","giornale","informazione"]
yes_words += ["sport","calcio","turismo","viaggi","viaggio","viaggiare"]

# %%
stopwords = ['a', "'anche'",'about', 'above', 'across', 'after', 'afterwards']
stopwords += ['again', 'against', 'all', 'almost', 'alone', 'along']
stopwords += ['already', 'also', 'although', 'always', 'am', 'among']
stopwords += ['amongst', 'amoungst', 'amount', 'an', 'and', 'another']
stopwords += ['any', 'anyhow', 'anyone', 'anything', 'anyway', 'anywhere']
stopwords += ['are', 'around', 'as', 'at', 'back', 'be', 'became']
stopwords += ['because', 'become', 'becomes', 'becoming', 'been']
stopwords += ['before', 'beforehand', 'behind', 'being', 'below']
stopwords += ['beside', 'besides', 'between', 'beyond', 'bill', 'both']
stopwords += ['bottom', 'but', 'by', 'call', 'can', 'cannot', 'cant']
stopwords += ['co', 'computer', 'con', 'could', 'couldnt', 'cry', 'de']
stopwords += ['describe', 'detail', 'did', 'do', 'done', 'down', 'due']
stopwords += ['during', 'each', 'eg', 'eight', 'either', 'eleven', 'else']
stopwords += ['elsewhere', 'empty', 'enough', 'etc', 'even', 'ever']
stopwords += ['every', 'everyone', 'everything', 'everywhere', 'except']
stopwords += ['few', 'fifteen', 'fifty', 'fill', 'find', 'fire', 'first']
stopwords += ['five', 'for', 'former', 'formerly', 'forty', 'found']
stopwords += ['four', 'from', 'front', 'full', 'further', 'get', 'give']
stopwords += ['go', 'had', 'has', 'hasnt', 'have', 'he', 'hence', 'her']
stopwords += ['here', 'hereafter', 'hereby', 'herein', 'hereupon', 'hers']
stopwords += ['herself', 'him', 'himself', 'his', 'how', 'however']
stopwords += ['hundred', 'i', 'ie', 'if', 'in', 'inc', 'indeed']
stopwords += ['interest', 'into', 'is', 'it', 'its', 'itself', 'keep']
stopwords += ['last', 'latter', 'latterly', 'least', 'less', 'ltd', 'made']
stopwords += ['many', 'may', 'me', 'meanwhile', 'might', 'mill', 'mine']
stopwords += ['more', 'moreover', 'most', 'mostly', 'move', 'much']
stopwords += ['must', 'my', 'myself', 'name', 'namely', 'neither', 'never']
stopwords += ['nevertheless', 'next', 'nine', 'no', 'nobody', 'none']
stopwords += ['noone', 'nor', 'not', 'nothing', 'now', 'nowhere', 'of']
stopwords += ['off', 'often', 'on','once', 'one', 'only', 'onto', 'or']
stopwords += ['other', 'others', 'otherwise', 'our', 'ours', 'ourselves']
stopwords += ['out', 'over', 'own', 'part', 'per', 'perhaps', 'please']
stopwords += ['put', 'rather', 're', 's', 'same', 'see', 'seem', 'seemed']
stopwords += ['seeming', 'seems', 'serious', 'several', 'she', 'should']
stopwords += ['show', 'side', 'since', 'sincere', 'six', 'sixty', 'so']
stopwords += ['some', 'somehow', 'someone', 'something', 'sometime']
stopwords += ['sometimes', 'somewhere', 'still', 'such', 'system', 'take']
stopwords += ['ten', 'than', 'that', 'the', 'their', 'them', 'themselves']
stopwords += ['then', 'thence', 'there', 'thereafter', 'thereby']
stopwords += ['therefore', 'therein', 'thereupon', 'these', 'they']
stopwords += ['thick', 'thin', 'third', 'this', 'those', 'though', 'three']
stopwords += ['three', 'through', 'throughout', 'thru', 'thus', 'to']
stopwords += ['together', 'too', 'top', 'toward', 'towards', 'twelve']
stopwords += ['twenty', 'two', 'un', 'under', 'until', 'up', 'upon']
stopwords += ['us', 'very', 'via', 'was', 'we', 'well', 'were', 'what']
stopwords += ['whatever', 'when', 'whence', 'whenever', 'where']
stopwords += ['whereafter', 'whereas', 'whereby', 'wherein', 'whereupon']
stopwords += ['wherever', 'whether', 'which', 'while', 'whither', 'who']
stopwords += ['whoever', 'whole', 'whom', 'whose', 'why', 'will', 'with']
stopwords += ['within', 'without', 'would', 'yet', 'you', 'your']
stopwords += ['yours', 'yourself', 'yourselves', "type:"]
stopwords += ['della', 'del', 'di',"dei"]

# %%
#http://www.oldbaileyonline.org/browse.jsp?id=t17800628-33&div=t17800628-33
#sono le funzioni di OBO, non tutte serviranno

def stripTags(pageContents):
    pageContents = str(pageContents)

    pageContents = pageContents #qual è il senso di questa cosa?

    inside = 0
    text = ''

    for char in pageContents:
        if char == '<':
            inside = 1
        elif (inside == 1 and char == '>'):
            inside = 0
        elif inside == 1:
            continue
        else:
            text += char

    return text


def stripNonAlphaNum(text):
    import re
    return re.compile(r'\W+', re.UNICODE).split(text)
    
# Given a list of words, return a dictionary of
# word-frequency pairs.

def wordListToFreqDict(wordlist):
    wordfreq = [wordlist.count(p) for p in wordlist]
    return dict(list(zip(wordlist,wordfreq)))
    
# Sort a dictionary of word-frequency pairs in
# order of descending frequency.

def sortFreqDict(freqdict):
    aux = [(freqdict[key], key) for key in freqdict]
    aux.sort()
    aux.reverse()
    return aux

# Given a list of words, remove any that are
# in a list of stop words.

def removeStopwords(wordlist, stopwords):
    return [w for w in wordlist if w not in stopwords]



#metodi migliori? magari una lista e poi un ciclo for, ma penso che oltre al tempo di scriverlo sia anche lungo. 
#Pensavo anche un ciclo in cui si confronta se ogni carattere è all'interno di una stringa composta da i caratteri da togliere
# if char in "!?,.":
# remove char
def stripPunctuations(pageContents):
    bad_chars = "?.,;:!"
    for char in bad_chars:
        pageContents = pageContents.replace(char,"")

# %%
#non riesco a togliere la sola punteggiatura dal testo, anche se questa funzione in teoria funziona
string ="ciao,mamma!come,va?"
stripPunctuations(string)

# %%
# open-webpage.py

import urllib.request, urllib.error, urllib.parse, obo

url = 'https://www.corriere.it'

response = urllib.request.urlopen(url)
webContent = response.read()
text = stripTags(webContent).lower()
wordlist = obo.stripNonAlphaNum(text)
text_list = text.split(" ")

print(text_list)
# Out:
# ["b'\\n\\n\\t\\t\\n\\t\\t\\n\\n\\t\\t\\n\\t\\t", '\\n\\t\\t\\n\\t\\t\\n\\t\\t\\n', '', '', '', '\\t\\n\\n\\t\\t\\n\\t\\t\\n\\t\\t\\n\\t\\t\\n\\n\\t\\t\\n\\n\\t\\t\\r\\n\\r\\n\\r\\n\\r\\n\\r\\n\\r\\n\\r\\n\\r\\n\\r\\n\\r\\n\\r\\n\\r\\n\\r\\n\\r\\n\\r\\n\\r\\n\\r\\n\\r\\n\\r\\n\\r\\n\\r\\n\\r\\n\\r\\n\\r\\n\\r\\n\\r\\n\\r\\n\\r\\n\\r\\n\\r\\n\\r\\n\\r\\n\\r\\n\\r\\n\\r\\n\\r\\n\\r\\n\\r\\n\\r\\n\\r\\n\\r\\n\\r\\n\\r\\n\\r\\n\\r\\n\\r\\n\\r\\n\\r\\n\\r\\n\\r\\n\\n\\t\\t\\n\\t\\n\\n\\n\\n\\n\\n\\n\\n\\t\\t\\n\\n\\t\\t\\n\\t\\t\\n', '', '', '', '\\t\\n\\n\\t\\t\\n\\n\\t\\t\\n\\n\\n\\t\\t\\n\\n\\t\\t', '', '\\n\\n\\t\\t', '', '\\n\\n\\t\\t', '', '\\n\\n\\t\\t\\t\\n\\t\\t', '\\t\\n\\t\\t\\t\\n\\n', '', '\\t\\t\\tcorriere', 'della', 'sera:', 'news', 'e', 'ultime', 'notizie', 'oggi', 'da', 'italia', 'e', 'mondo{\\n', '', '', '', '', '', '"@context":', '"http://schema.org",\\n', '', '', '', '', '', '"@type":', '"newsmediaorganization",\\n', '', '', '', '', '', '"name":', '"corriere', 'della', 'sera",\\n', '', '', '', '', '', '"logo":', '', '', '{\\n', '', '', '', '', '', '', '', '"@type":', '"imageobject",\\n', '', '', '', '', '', '', '', '"url":', '"https://images2.corriereobjects.it/includes2013/libs/css/assets/logo/logo_header_hp.svg",\\n', '', '', '', '', '', '', '', '"width":', '400,\\n', '', '', '', '', '', '', '', '"height":', '80\\n', '', '', '', '', '', '},\\n', '', '', '', '', '', '"sameas":', '', '', '[\\n', '', '', '', '', '', '', '', '"https://www.facebook.com/corrieredellasera/",\\n', '', '', '', '', '', '', '', '"https://twitter.com/corriere"\\n', '', '', '', '', '', '],\\n', '', '', '', '', '', '"foundingdate":', '"1876-03-05",\\n', '', '', '', '', '', '"url":', '"https://www.corriere.it/",\\n', '', '', '', '', '', '"ethicspolicy":', '"https://www.corriere.it/trust/codice_etico.shtml",\\n', '', '', '', '', '', '"contactpoint":', '', '', '[\\n', '', '', '', '{\\n', '', '', '', '', '', '', '', '', '', '"@type":', '"contactpoint",\\n', '', '', '', '', '', '', '', '', '', '"contacttype":', '"public', 'engagement",\\n', '', '', '', '', '', '', '', '', '', '"email":', '"scriverelamaildicorriere@corriere.it",\\n', '', '', '', '', '', '', '', '', '', '"url":', '"https://www.corriere.it/privacy.shtml"\\n', '', '', '', '', '', '', '', '}\\n', '', '', '', '', '', ']\\n', '', '', '', '}var', 'namelocal,device="desktop",rpg2019=!0,_todaydate="20200817",server_date="08-17-20-33-1-48-18-2020-25",server_date_iso="2020-08-17t16:48:25z",server_date_timestamp="1597682905",server_date_split=server_date.split("-"),server_hour=server_date_split[6]/1,uuid="(none)",firstpubmobile="(none)",sezione="home",sottosezione="default",section_lev1="home",section_lev2="default",channel_page_title="(none)",tipologia="home",subtype="(none)",competizione="(none)",firstpub="(none)",firma="(none)",antiadblocktype=2,isadblockenable=!0,loginlogger=window._logger?_logger.get("login"):window.console,ishotjarenabled=falsevar', 'cpmt_checkfunction=function(n){var', 'e="undefined";try{n=typeof', 'n===e?5334:n}catch(c){n=typeof', 'n===e?null:n}var', 'c=new', 'regexp("cpmt_xa=[^;]*,?("+n+"),?");return', 'null!==document.cookie.match(c)||-1!==document.cookie.indexof("__ric=")};"undefined"==typeof', 'privacyok&&(window.privacyok=cpmt_checkfunction())window.innerwidthrcsad_listpos="position1,left1,right1,topleft,frame1"rcsad_sitepage="corriere.it/homepage/hpcorriere"\\n\\t\\n//rcsad_disabled', '=', 'true;\\n\\nvar', 'v_chartbeat', '=', 'true;', 'var', 'utag_data', '=', '{};', 'var', 'utag_cfg_ovrd', '=', '{', 'domain', ':', "\\'components2.rcsobjects.it\\',", 'path', ':', '"https://components2.rcsobjects.it/rcs_tealium/v1/distro/corriere/preprod/",', 'env:', "\\'preprod\\'", '};', 'var', 'config', '=', '{', 'getflavor:', 'function(){', 'return', "\\'desktop\\';", '},', 'components:', '[{', 'type:', "\\'ext\\',", 'src:', "\\'https://components2.rcsobjects.it/rcs_tealium/v1/distro/corriere/preprod/utag.sync.js?v=08ca22378728aaf3e34665e5c4c423f5\\',", 'priority:', '1', '},' ...

# %%
#avevo fatto "not in" + remove, ma non funziona

      #  list_yes_words = []
     #   def saveYesWords(wordlist, yes_words):
            for word in wordlist:
                if word in yes_words:
                    print(word)
                    list_yes_words.append(word)
            return list_yes_words

        lista_di_prova = ["ciao","mamma","fashion","due","nonna","kfsf","tre"]

        saveYesWords(lista_di_prova, yes_words)
        list_yes_words
# Out:
#   File "<tokenize>", line 11
#     lista_di_prova = ["ciao","mamma","fashion","due","nonna","kfsf","tre"]
#     ^
# IndentationError: unindent does not match any outer indentation level

# %%
list_saved_words = []
def avoidStopWords(wordlist, stopwords):
    for word in wordlist:
        if word not in stopwords:
            print(word)
            list_saved_words.append(word)
    return list_saved_words

avoidStopWords(wordlist, stopwords)
# Out:
# b
# n
# n
# t
# t
# n
# t
# t
# n
# n
# t
# t
# n
# t
# t
# n
# t
# t
# n
# t
# t
# n
# t
# t
# n
# t
# n
# n
# t
# t
# n
# t
# t
# n
# t
# t
# n
# t
# t
# n
# n
# t
# t
# n
# n
# t
# t
# r
# n
# r
# n
# r
# n
# r
# n
# r
# n
# r
# n
# r
# n
# r
# n
# r
# n
# r
# n
# r
# n
# r
# n
# r
# n
# r
# n
# r
# n
# r
# n
# r
# n
# r
# n
# r
# n
# r
# n
# r
# n
# r
# n
# r
# n
# r
# n
# r
# n
# r
# n
# r
# n
# r
# n
# r
# n
# r
# n
# r
# n
# r
# n
# r
# n
# r
# n
# r
# n
# r
# n
# r
# n
# r
# n
# r
# n
# r
# n
# r
# n
# r
# n
# r
# n
# r
# n
# r
# n
# r
# n
# r
# n
# r
# n
# r
# n
# r
# n
# n
# t
# t
# n
# t
# n
# n
# n
# n
# n
# n
# n
# n
# t
# t
# n
# n
# t
# t
# n
# t
# t
# n
# t
# n
# n
# t
# t
# n
# n
# t
# t
# n
# n
# n
# t
# t
# n
# n
# t
# t
# n
# n
# t
# t
# n
# n
# t
# t
# n
# n
# t
# t
# t
# n
# t
# t
# t
# n
# t
# t
# t
# n
# n
# t
# t
# tcorriere
# sera
# news
# e
# ultime
# notizie
# oggi
# da
# italia
# e
# mondo
# n
# context
# http
# schema
# org
# n
# type
# newsmediaorganization
# n
# corriere
# sera
# n
# logo
# n
# type
# imageobject
# n
# url
# https
# images2
# corriereobjects
# includes2013
# libs
# css
# assets
# logo
# logo_header_hp
# svg
# n
# width
# 400
# n
# height
# 80
# n
# n
# sameas
# n
# https
# www
# facebook
# com
# corrieredellasera
# n
# https
# twitter
# com
# corriere
# n
# n
# foundingdate
# 1876
# 03
# 05
# n
# url
# https
# www
# corriere
# n
# ethicspolicy
# https
# www
# corriere
# trust
# codice_etico
# shtml
# n
# contactpoint
# n
# n
# type
# contactpoint
# n
# contacttype
# public
# engagement
# n
# email
# scriverelamaildicorriere
# corriere
# n
# url
# https
# www
# corriere
# privacy
# shtml
# n
# n
# n
# var
# namelocal
# device
# desktop
# rpg2019
# 0
# _todaydate
# 20200817
# server_date
# 08
# 17
# 20
# 33
# 1
# 45
# 18
# 2020
# 35
# server_date_iso
# 2020
# 08
# 17t16
# 45
# 35z
# server_date_timestamp
# 1597682735
# server_date_split
# server_date
# split
# server_hour
# server_date_split
# 6
# 1
# uuid
# firstpubmobile
# sezione
# home
# sottosezione
# default
# section_lev1
# home
# section_lev2
# default
# channel_page_title
# tipologia
# home
# subtype
# competizione
# firstpub
# firma
# antiadblocktype
# 2
# isadblockenable
# 0
# loginlogger
# window
# _logger
# _logger
# login
# window
# console
# ishotjarenabled
# falsevar
# cpmt_checkfunction
# function
# n
# var
# e
# undefined
# try
# n
# typeof
# n
# e
# 5334
# n
# catch
# c
# n
# typeof
# n
# e
# null
# n
# var
# c
# new
# regexp
# cpmt_xa
# n
# return
# null
# document
# cookie
# match
# c
# 1
# document
# cookie
# indexof
# __ric
# undefined
# typeof
# privacyok
# window
# privacyok
# cpmt_checkfunction
# window
# innerwidthrcsad_listpos
# position1
# left1
# right1
# topleft
# frame1
# rcsad_sitepage
# corriere
# homepage
# hpcorriere
# n
# t
# n
# rcsad_disabled
# true
# n
# nvar
# v_chartbeat
# true
# var
# utag_data
# var
# utag_cfg_ovrd
# domain
# components2
# rcsobjects
# path
# https
# components2
# rcsobjects
# rcs_tealium
# v1
# distro
# corriere
# preprod
# env
# preprod
# var
# config
# getflavor
# function
# return
# desktop
# components
# type
# ext
# src
# https
# components2
# rcsobjects
# rcs_tealium
# v1
# distro
# corriere
# preprod
# utag
# sync
# js
# v
# 08ca22378728aaf3e34665e5c4c423f5
# priority
# 1
# type
# ext
# src
# https
# components2
# rcsobjects
# rcs_tealium
# v1
# distro
# corriere
# preprod
# utag
# js
# v
# 6fda832769c2dc71bb27f3654f528be8
# priority
# 2
# type
# ext
# src
# apw
# js
# v
# 4
# priority
# 1
# type
# ext
# src
# apw
# js
# v
# 4
# f
# mod
# priority
# 2
# type
# module
# src
# legacy
# jquery
# priority
# 1
# events
# target
# document
# eventname
# domcontentloaded
# type
# module
# src
# global
# desktop
# default
# priority
# 2
# events
# target
# document
# eventname
# domcontentloaded
# type
# ext
# src
# https
# components2
# corriereobjects
# rcs_cor_userauth
# v1
# index
# min
# js
# v
# 6732d569e8edfa99e3a96ebd4bbebb35
# priority
# 5
# legacy
# true
# flavors
# desktop
# tablet
# events
# target
# window
# eventname
# load
# callback
# function
# const
# component
# new
# rcscoruserauth
# menu
# user
# component
# render
# type
# ext
# src
# https
# components2
# corriereobjects
# rcs_cor_menu
# v3
# index
# min
# js
# v
# 70a7c11eb3fbaa77b37aa67e9f31b9ac
# priority
# 5
# legacy
# true
# flavors
# desktop
# tablet
# events
# target
# window
# eventname
# load
# callback
# function
# var
# component
# new
# rcscormenu
# currentdevice
# component
# render
# type
# style
# src
# https
# css2
# corriereobjects
# includes2013
# libs
# css
# vendor
# login_com
# css
# priority
# 10
# flavors
# desktop
# tablet
# events
# target
# document
# eventname
# rcscoruserauth
# start
# type
# style
# src
# https
# css2
# corriereobjects
# includes2013
# libs
# css
# vendor
# plugins
# jquery
# fancybox
# css
# priority
# 10
# flavors
# desktop
# tablet
# events
# target
# document
# eventname
# rcscoruserauth
# start
# type
# ext
# src
# https
# components2
# corriereobjects
# rcs_cor_top
# search
# bar
# v2
# index
# min
# js
# priority
# 6
# flavors
# desktop
# tablet
# events
# target
# window
# eventname
# load
# callback
# function
# var
# componentsearch
# new
# rcscortopsearchbar
# componentsearch
# render
# type
# module
# src
# hotjarloader
# priority
# 10
# legacy
# true
# events
# target
# window
# eventname
# load
# type
# ext
# src
# https
# js2
# corriereobjects
# includes2013
# libs
# js
# vwo
# js
# priority
# 10
# type
# module
# src
# global
# desktop
# home
# priority
# 1
# events
# target
# window
# eventname
# load
# type
# module
# src
# menu
# sticky
# home
# priority
# 2
# flavors
# desktop
# tablet
# events
# target
# document
# eventname
# domcontentloaded
# type
# module
# src
# sponsorstrip
# onelementspresence
# targets
# bck
# media
# list
# sponsor
# event
# domcontentloaded
# flavors
# desktop
# tablet
# priority
# 3
# type
# ext
# src
# https
# imasdk
# googleapis
# com
# js
# sdkloader
# ima3
# js
# flavors
# desktop
# tablet
# priority
# 2
# type
# ext
# src
# https
# components2
# corriereobjects
# rcs_most
# viewed
# v1
# index
# min
# js
# v
# b5ab2fc15071edab92338df296a3cb0c
# priority
# 30
# flavors
# tablet
# desktop
# events
# target
# document
# eventname
# domcontentloaded
# callback
# function
# var
# component
# new
# rcsmostviewed
# bk_cop_011
# letti
# component
# render
# type
# ext
# src
# https
# components2
# corriereobjects
# rcs_cor_weather
# v2
# index
# min
# js
# priority
# 6
# flavors
# desktop
# events
# target
# document
# eventname
# domcontentloaded
# callback
# function
# var
# component
# new
# rcscorweather
# bck
# meteo
# component
# render
# type
# ext
# src
# https
# components2
# corriereobjects
# rcs_mc_widget_fe
# v0
# index
# min
# js
# v
# ff093a5a0219ae2472779871d805e68c
# priority
# 6
# onviewport
# target
# matchcenter
# widget
# offset
# 100
# type
# style
# src
# https
# components2
# corriereobjects
# rcs_mc_widget_fe
# v0
# main
# css
# v
# cfb340fc62782646d5930a290635dc7d
# priority
# 2
# onviewport
# target
# matchcenter
# widget
# offset
# 100
# type
# ext
# src
# https
# components2
# corriereobjects
# rcs_cor_exit
# page
# v2
# index
# min
# js
# priority
# 20
# flavors
# desktop
# callback
# function
# var
# component
# new
# rcscorexitpage
# component
# render
# type
# ext
# src
# https
# components2
# corriereobjects
# rcs_videoplayer
# v2
# index
# min
# js
# v
# 45f7e0549262cc19d851fe9645b120fe
# priority
# 3
# callback
# function
# window
# playerfactory
# new
# rcsvideo
# console
# log
# player
# loaded
# type
# ext
# src
# https
# components2
# corriereobjects
# rcs_video
# manager
# v2
# index
# min
# js
# v
# 8d7ac8dddd8e39b135855997721f2988
# legacy
# true
# priority
# 4
# events
# target
# window
# eventname
# load
# callback
# function
# var
# rcsvideocomponent
# new
# rcsvideomanager
# player
# rcsvideocomponent
# render
# type
# ext
# src
# https
# components
# rcsobjects
# rcs_gallery
# manager
# v2
# index
# min
# js
# v
# fa3ed060820b302a28883f89a339dc6c
# legacy
# true
# events
# target
# document
# eventname
# domcontentloaded
# callback
# function
# var
# rcsgallerymanagercomponent
# new
# rcsgallerymanager
# bck
# carousel
# news
# rcsgallerymanagercomponent
# render
# type
# ext
# src
# https
# js2
# corriereobjects
# volocom
# volocom
# js
# flavors
# desktop
# tablet
# priority
# 10
# type
# ext
# src
# https
# widgets
# outbrain
# com
# outbrain
# js
# priority
# 5
# legacy
# false
# events
# target
# window
# eventname
# load
# callback
# function
# console
# log
# outbrain
# type
# ext
# src
# https
# components2
# corriereobjects
# rcs_anti
# adblocker
# v1
# index
# min
# js
# v
# d56fcbb826af45acd04dcdb4ac108dea
# priority
# 8
# legacy
# true
# events
# target
# document
# eventname
# adblockactivated
# callback
# function
# var
# rcsantiadblockercomponent
# new
# rcsantiadblocker
# 1
# corriere
# rcsantiadblockercomponent
# render
# document
# addeventlistener
# domcontentloaded
# function
# var
# currentdevice
# config
# getflavor
# var
# rcsorchestrator
# new
# rcsorchestrator
# config
# rcsorchestrator
# load
# desktop
# n
# n
# t
# t
# t
# n
# t
# t
# t
# t
# da
# riportare
# nel
# layout
# n
# t
# t
# t
# t
# rcs
# video
# sticky
# video
# padding
# 0
# 0
# 4
# 375rem
# n
# t
# t
# t
# t
# bck
# navbar
# submenu
# list
# tertiary
# img
# width
# 15px
# margin
# right
# 6px
# n
# t
# t
# t
# t
# t_aldo_cazzullo
# background
# size
# 630px
# n
# t
# t
# t
# t
# fascione
# mc
# n
# t
# t
# t
# t
# font
# face
# n
# t
# t
# t
# t
# tfont
# family
# main
# condensed_bold
# n
# t
# t
# t
# t
# tfont
# style
# normal
# n
# t
# t
# t
# t
# tfont
# weight
# normal
# n
# t
# t
# t
# t
# tsrc
# url
# includes2013
# libs
# css
# fonts
# brera
# brecnbd
# webfont
# eot
# n
# t
# t
# t
# t
# tsrc
# url
# includes2013
# libs
# css
# fonts
# brera
# brecnbd
# webfont
# eot
# iefix
# format
# embedded
# opentype
# url
# includes2013
# libs
# css
# fonts
# brera
# brecnbd
# webfont
# woff
# format
# woff
# url
# includes2013
# libs
# css
# fonts
# brera
# brecnbd
# webfont
# ttf
# format
# truetype
# url
# includes2013
# libs
# css
# fonts
# brera
# brecnbd
# webfont
# svg
# breracondensedbold
# format
# svg
# n
# t
# t
# t
# t
# t
# n
# t
# t
# t
# t
# font
# face
# n
# t
# t
# t
# t
# tfont
# family
# main
# condensed_regular
# n
# t
# t
# t
# t
# tfont
# style
# normal
# n
# t
# t
# t
# t
# tfont
# weight
# normal
# n
# t
# t
# t
# t
# tsrc
# url
# includes2013
# libs
# css
# fonts
# brera
# brecnrg
# webfont
# eot
# n
# t
# t
# t
# t
# tsrc
# url
# includes2013
# libs
# css
# fonts
# brera
# brecnrg
# webfont
# eot
# iefix
# format
# embedded
# opentype
# url
# includes2013
# libs
# css
# fonts
# brera
# brecnrg
# webfont
# woff
# format
# woff
# url
# includes2013
# libs
# css
# fonts
# brera
# brecnrg
# webfont
# ttf
# format
# truetype
# url
# includes2013
# libs
# css
# fonts
# brera
# brecnrg
# webfont
# svg
# breracondensedregular
# format
# svg
# n
# t
# t
# t
# t
# t
# n
# n
# n
# t
# t
# t
# t
# t
# provvisorio
# mf
# n
# t
# t
# t
# t
# t
# bck
# media
# news
# media
# news__footer
# 33
# p
# n
# t
# t
# t
# t
# t
# tline
# height
# 1
# 1
# n
# t
# t
# t
# t
# t
# n
# t
# t
# t
# t
# t
# provvisorio
# mf
# n
# n
# t
# t
# t
# t
# tspan
# hour
# visibility
# hidden
# n
# n
# n
# t
# t
# t
# n
# n
# t
# t
# t
# n
# n
# t
# t
# t
# t
# corriere
# 4471
# n
# t
# t
# t
# tlocalstorage
# removeitem
# stickyvideocounter
# n
# t
# t
# t
# t
# n
# t
# t
# t
# t
# provvisorio
# n
# t
# t
# t
# tfetch
# https
# static2
# corriereobjects
# includes_methode
# 2020
# last_updated_hour
# html
# v
# 20200817183720
# function
# response
# n
# t
# t
# t
# t
# treturn
# response
# text
# n
# t
# t
# t
# t
# function
# html
# n
# t
# t
# t
# t
# tvar
# parser
# new
# domparser
# n
# t
# t
# t
# t
# tvar
# doc
# parser
# parsefromstring
# html
# text
# html
# n
# t
# t
# t
# t
# tvar
# hour
# doc
# queryselector
# span
# hour
# textcontent
# n
# t
# t
# t
# t
# tdocument
# queryselector
# span
# hour
# innerhtml
# hour
# n
# t
# t
# t
# t
# tdocument
# queryselector
# span
# hour
# style
# visibility
# visible
# n
# n
# t
# t
# t
# t
# catch
# function
# err
# n
# t
# t
# t
# t
# tdocument
# queryselector
# span
# hour
# style
# visibility
# visible
# n
# t
# t
# t
# t
# tconsole
# warn
# went
# wrong
# err
# n
# t
# t
# t
# t
# n
# t
# t
# t
# t
# provvisorio
# n
# t
# t
# t
# t
# n
# n
# t
# t
# n
# t
# t
# n
# n
# t
# n
# n
# n
# twindow
# eventdfpready
# googletag
# cmd
# push
# function
# googletag
# display
# rcsad_position1
# document
# addeventlistener
# eventdfpready
# function
# o
# googletag
# cmd
# push
# function
# googletag
# display
# rcsad_position1
# 1
# n
# n
# t
# n
# t
# t
# n
# t
# t
# n
# t
# t
# t
# t
# n
# t
# t
# n
# n
# t
# t
# n
# t
# t
# n
# t
# t
# n
# t
# t
# n
# t
# t
# n
# n
# n
# t
# t
# n
# t
# t
# n
# t
# t
# n
# t
# t
# n
# n
# t
# t
# n
# n
# t
# t
# r
# n
# r
# n
# r
# n
# r
# n
# r
# n
# r
# n
# r
# n
# r
# n
# r
# n
# r
# n
# r
# n
# r
# n
# r
# n
# r
# n
# r
# n
# r
# n
# r
# n
# r
# n
# r
# n
# r
# n
# r
# n
# r
# n
# r
# n
# r
# n
# r
# n
# r
# n
# r
# n
# r
# n
# r
# n
# r
# n
# r
# n
# r
# n
# r
# n
# r
# n
# r
# n
# r
# n
# r
# n
# r
# n
# r
# n
# r
# n
# r
# n
# r
# n
# r
# n
# r
# n
# r
# n
# r
# n
# r
# n
# r
# n
# r
# n
# r
# n
# n
# n
# t
# t
# sezioni
# n
# nhome
# n
# n
# nopinioni
# n
# n
# nle
# firme
# n
# n
# n
# lettere
# al
# direttore
# n
# n
# n
# il
# caff
# egrave
# gramellini
# n
# n
# n
# lo
# dico
# al
# corriere
# n
# n
# n
# italians
# beppe
# severgnini
# n
# n
# nil
# twitter
# direttore
# n
# n
# n
# padiglione
# italia
# n
# n
# n
# ultimo
# banco
# d
# rsquo
# avenia
# n
# n
# n
# letti
# da
# rifare
# d
# avenia
# n
# n
# n
# facce
# nuove
# n
# n
# n
# n
# ndatablog
# n
# n
# nenglish
# chinese
# n
# n
# n
# editorials
# english
# version
# n
# n
# n
# n
# nmenu
# n
# n
# n
# n
# ncibo
# regola
# d
# arte
# n
# n
# n
# n
# niodonna
# n
# n
# nstyle
# n
# n
# n27ora
# n
# n
# nextramamme
# n
# n
# nil
# tempo
# delle
# donne
# 2019
# n
# n
# nil
# tempo
# delle
# donne
# 2018
# n
# n
# nla
# felicit
# agrave
# adesso
# n
# n
# nuomini
# ndash
# segni
# cambiamento
# n
# n
# n
# n
# nmoda
# n
# n
# nbeauty
# n
# n
# nmoda
# amp
# business
# n
# n
# nsfilate
# donna
# n
# n
# nsfilate
# uomo
# n
# n
# n
# n
# npianeta2020
# n
# n
# nsolferino
# libri
# n
# n
# nquimamme
# n
# n
# nedizioni
# locali
# bergamobolognabresciafirenzemilano
# vivimilanoromamezzogiorno
# baricasertacataniafoggialeccenapolipalermosalernotorinoveneto
# bellunopadovarovigotrevisovenetoveneziaveronavicenzacorrieretvarchiviotrovocasatrovolavorocruciverbaservizi
# abbonamentidigital
# editionnewsletterrcs
# academycruciverba
# corriereattiva
# le
# notifichedizionariotrovocasatrovolavorotrovoastetrovobandicorriere
# storecomunilotterie
# e
# giochimeteobuonpertutti
# volantininecrologiscrivicerca
# abbonatilo
# stato
# tuo
# abbonamento
# placeholder
# egrave
# sospeso
# verificare
# clicca
# qui
# carta
# credito
# egrave
# scaduta
# aggiornare
# clicca
# qui
# carta
# credito
# egrave
# scadenza
# aggiornare
# clicca
# qui
# login
# alertoffermenu
# n
# display
# important
# n
# il
# mio
# corrierenewsletter
# gestisci
# profilo
# logoutcerca
# nel
# sitoin
# corriere
# viagginel
# dizionario
# window
# eventdfpready
# googletag
# cmd
# push
# function
# googletag
# display
# rcsad_left1
# document
# addeventlistener
# eventdfpready
# function
# e
# googletag
# cmd
# push
# function
# googletag
# display
# rcsad_left1
# 1
# luned
# xec
# 17
# agosto
# 2020
# aggiornato
# alle
# nbsp
# 18
# 36
# n
# meteo
# deg
# milanomilano
# lorenteggiomilano
# baggiomilano
# baronawindow
# eventdfpready
# googletag
# cmd
# push
# function
# googletag
# display
# rcsad_right1
# document
# addeventlistener
# eventdfpready
# function
# e
# googletag
# cmd
# push
# function
# googletag
# display
# rcsad_right1
# 1
# n
# n
# t
# t
# n
# t
# n
# n
# twindow
# eventdfpready
# googletag
# cmd
# push
# function
# googletag
# display
# rcsad_topleft
# document
# addeventlistener
# eventdfpready
# function
# e
# googletag
# cmd
# push
# function
# googletag
# display
# rcsad_topleft
# 1
# n
# n
# t
# t
# n
# t
# t
# n
# n
# t
# t
# t
# t
# r
# n
# r
# n
# r
# n
# n
# t
# t
# t
# t
# n
# t
# t
# t
# t
# n
# t
# t
# t
# t
# n
# t
# n
# n
# t
# t
# n
# t
# n
# n
# n
# n
# n
# n
# n
# n
# n
# n
# r
# n
# t
# t
# t
# t
# t
# t
# r
# n
# t
# t
# t
# t
# t
# t
# temi
# caldi
# oggi
# r
# n
# t
# t
# t
# t
# t
# t
# r
# n
# t
# t
# t
# t
# t
# t
# t
# t
# r
# n
# t
# t
# t
# t
# t
# t
# t
# t
# tbollettino
# coronavirus
# n
# r
# n
# t
# t
# t
# t
# t
# t
# t
# t
# r
# n
# t
# t
# t
# t
# t
# t
# t
# t
# tbonus
# 600
# euro
# n
# r
# n
# t
# t
# t
# t
# t
# t
# t
# t
# r
# n
# t
# t
# t
# t
# t
# t
# t
# t
# tchampions
# league
# n
# r
# n
# t
# t
# t
# t
# t
# t
# t
# t
# r
# n
# t
# t
# t
# t
# t
# t
# t
# r
# n
# t
# t
# t
# t
# t
# t
# r
# n
# t
# t
# t
# t
# t
# n
# n
# n
# n
# n
# n
# n
# n
# n
# n
# n
# n
# n
# n
# n
# n
# t
# r
# n
# r
# n
# t
# t
# r
# n
# r
# n
# t
# t
# t
# t
# r
# n
# t
# t
# t
# t
# r
# n
# r
# n
# r
# n
# n
# r
# n
# r
# n
# r
# n
# r
# n
# r
# n
# r
# n
# r
# n
# r
# n
# r
# n
# r
# n
# r
# n
# r
# n
# r
# n
# r
# n
# r
# n
# r
# n
# r
# n
# r
# n
# r
# n
# r
# n
# r
# n
# r
# n
# r
# n
# r
# n
# r
# n
# r
# n
# r
# n
# r
# n
# r
# n
# r
# n
# r
# n
# r
# n
# r
# n
# r
# n
# r
# n
# r
# n
# r
# n
# r
# n
# r
# n
# r
# n
# r
# n
# r
# n
# r
# n
# r
# n
# r
# n
# r
# n
# r
# n
# r
# n
# r
# n
# r
# n
# n
# n
# t
# tvar
# load
# function
# n
# callrevizoneid
# mkt_mixed_hp_01
# 293
# mkt_mixed_hp_02
# 295
# mkt_mixed_hp_03
# 297
# bacheca_allsite_01
# 187
# bacheca_allsite_02
# 189
# bacheca_allsite_03
# 191
# bacheca_allsite_04
# 193
# boxpromo_allsite_01
# 195
# box_mkt_hp_spalla_dx
# 417
# hp_advmkt_01
# 19
# box_mkt_hp_spalla_sx
# 1139
# n
# nwindow
# onload
# load
# window
# _taboola
# window
# _taboola
# _taboola
# push
# flush
# 0
# function
# gtag
# datalayer
# push
# arguments
# window
# datalayer
# window
# datalayer
# gtag
# js
# new
# date
# gtag
# config
# ua
# 21108977
# 1
# anonymize_ip
# 0
# samplerate
# 10
# sample_rate
# 10
# var
# _sf_async_config
# _sf_async_config
# _sf_async_config
# uid
# 48229
# _sf_async_config
# domain
# corriere
# _sf_async_config
# flickercontrol
# 1
# _sf_async_config
# usecanonical
# 0
# _sf_async_config
# autodetect
# 1
# var
# _sf_startpt
# new
# date
# gettime
# var
# whicmainsectioncb
# home
# whicsubsectioncb
# default
# tempsectionvar
# home
# idchartbeat
# 48229
# moda
# whicmainsectioncb
# tempsectionvar
# whicmainsectioncb
# modacorriere
# 1
# undefined
# typeof
# privacyok
# 1
# privacyok
# settimeout
# function
# var
# e
# document
# createelement
# script
# t
# document
# getelementsbytagname
# script
# 0
# e
# src
# document
# location
# protocol
# script
# crazyegg
# com
# pages
# scripts
# 0030
# 5860
# js
# math
# floor
# new
# date
# gettime
# 36e5
# e
# async
# 0
# e
# type
# text
# javascript
# t
# parentnode
# insertbefore
# e
# t
# 1
# ts_debug
# 1document
# addeventlistener
# domcontentloaded
# function
# var
# t
# setinterval
# function
# undefined
# typeof
# utag
# function
# typeof
# utag
# track
# clearinterval
# t
# try
# utag_data
# send_page_bottom
# catch
# t
# 100
# function
# r
# r
# r
# nlsq
# function
# n
# t
# e
# o
# c
# return
# e
# o
# r
# document
# createelement
# script
# async
# 1
# e
# src
# http
# r
# location
# protocol
# http
# https
# cdn
# gl
# imrworldwide
# com
# conf
# n
# js
# ns
# c
# o
# getelementsbytagname
# script
# 0
# parentnode
# insertbefore
# e
# c
# r
# r
# g
# t
# ggpm
# function
# n
# t
# e
# o
# c
# r
# q
# r
# q
# push
# n
# t
# e
# o
# c
# r
# window
# nolbundle
# window
# gg
# window
# nolbundle
# nlsq
# p07deb19a
# 591c
# 41a4
# 9748
# bdb9a5fc0253
# corriere
# clientid
# 901600
# vcid
# b01
# function
# o
# o
# o
# nlsq
# function
# t
# c
# n
# e
# return
# e
# o
# document
# createelement
# script
# async
# 1
# e
# src
# http
# o
# location
# protocol
# http
# https
# cdn
# gl
# imrworldwide
# com
# conf
# t
# js
# c
# ns
# getelementsbytagname
# script
# 0
# parentnode
# insertbefore
# e
# o
# c
# o
# c
# g
# n
# ggpm
# function
# t
# n
# e
# o
# c
# q
# o
# c
# q
# push
# t
# n
# e
# o
# c
# window
# nolbundle
# var
# nsdkinstance
# nolbundle
# nlsq
# p550170f9
# 6641
# 4f5a
# adca
# c327af68ebc0
# nlsninstance
# nielsenmetadata
# type
# static
# assetid
# 95cfeef87da86e3a78ac24b0f5080abc
# section
# corrierehomepage_brw
# nsdkinstance
# ggpm
# staticstart
# nielsenmetadata
# n
# n
# n
# t
# t
# n
# n
# t
# n
# n
# ['b',
#  'n',
#  'n',
#  't',
#  't',
#  'n',
#  't',
#  't',
#  'n',
#  'n',
#  't',
#  't',
#  'n',
#  't',
#  't',
#  'n',
#  't',
#  't',
#  'n',
#  't',
#  't',
#  'n',
#  't',
#  't',
#  'n',
#  't',
#  'n',
#  'n',
#  't',
#  't',
#  'n',
#  't',
#  't',
#  'n',
#  't',
#  't',
#  'n',
#  't',
#  't',
#  'n',
#  'n',
#  't',
#  't',
#  'n',
#  'n',
#  't',
#  't',
#  'r',
#  'n',
#  'r',
#  'n',
#  'r',
#  'n',
#  'r',
#  'n',
#  'r',
#  'n',
#  'r',
#  'n',
#  'r',
#  'n',
#  'r',
#  'n',
#  'r',
#  'n',
#  'r',
#  'n',
#  'r',
#  'n',
#  'r',
#  'n',
#  'r',
#  'n',
#  'r',
#  'n',
#  'r',
#  'n',
#  'r',
#  'n',
#  'r',
#  'n',
#  'r',
#  'n',
#  'r',
#  'n',
#  'r',
#  'n',
#  'r',
#  'n',
#  'r',
#  'n',
#  'r',
#  'n',
#  'r',
#  'n',
#  'r',
#  'n',
#  'r',
#  'n',
#  'r',
#  'n',
#  'r',
#  'n',
#  'r',
#  'n',
#  'r',
#  'n',
#  'r',
#  'n',
#  'r',
#  'n',
#  'r',
#  'n',
#  'r',
#  'n',
#  'r',
#  'n',
#  'r',
#  'n',
#  'r',
#  'n',
#  'r',
#  'n',
#  'r',
#  'n',
#  'r',
#  'n',
#  'r',
#  'n',
#  'r',
#  'n',
#  'r',
#  'n',
#  'r',
#  'n',
#  'r',
#  'n',
#  'r',
#  'n',
#  'r',
#  'n',
#  'r',
#  'n',
#  'r',
#  'n',
#  'r',
#  'n',
#  'n',
#  't',
#  't',
#  'n',
#  't',
#  'n',
#  'n',
#  'n',
#  'n',
#  'n',
#  'n',
#  'n',
#  'n',
#  't',
#  't',
#  'n',
#  'n',
#  't',
#  't',
#  'n',
#  't',
#  't',
#  'n',
#  't',
#  'n',
#  'n',
#  't',
#  't',
#  'n',
#  'n',
#  't',
#  't',
#  'n',
#  'n',
#  'n',
#  't',
#  't',
#  'n',
#  'n',
#  't',
#  't',
#  'n',
#  'n',
#  't',
#  't',
#  'n',
#  'n',
#  't',
#  't',
#  'n',
#  'n',
#  't',
#  't',
#  't',
#  'n',
#  't',
#  't',
#  't',
#  'n',
#  't',
#  't',
#  't',
#  'n',
#  'n',
#  't',
#  't',
#  'tcorriere',
#  'sera',
#  'news',
#  'e',
#  'ultime',
#  'notizie',
#  'oggi',
#  'da',
#  'italia',
#  'e',
#  'mondo',
#  'n',
#  'context',
#  'http',
#  'schema',
#  'org',
#  'n',
#  'type',
#  'newsmediaorganization',
#  'n',
#  'corriere',
#  'sera',
#  'n',
#  'logo',
#  'n',
#  'type',
#  'imageobject',
#  'n',
#  'url',
#  'https',
#  'images2',
#  'corriereobjects',
#  'includes2013',
#  'libs',
#  'css',
#  'assets',
#  'logo',
#  'logo_header_hp',
#  'svg',
#  'n',
#  'width',
#  '400',
#  'n',
#  'height',
#  '80',
#  'n',
#  'n',
#  'sameas',
#  'n',
#  'https',
#  'www',
#  'facebook',
#  'com',
#  'corrieredellasera',
#  'n',
#  'https',
#  'twitter',
#  'com',
#  'corriere',
#  'n',
#  'n',
#  'foundingdate',
#  '1876',
#  '03',
#  '05',
#  'n',
#  'url',
#  'https',
#  'www',
#  'corriere',
#  'n',
#  'ethicspolicy',
#  'https',
#  'www',
#  'corriere',
#  'trust',
#  'codice_etico',
#  'shtml',
#  'n',
#  'contactpoint',
#  'n',
#  'n',
#  'type',
#  'contactpoint',
#  'n',
#  'contacttype',
#  'public',
#  'engagement',
#  'n',
#  'email',
#  'scriverelamaildicorriere',
#  'corriere',
#  'n',
#  'url',
#  'https',
#  'www',
#  'corriere',
#  'privacy',
#  'shtml',
#  'n',
#  'n',
#  'n',
#  'var',
#  'namelocal',
#  'device',
#  'desktop',
#  'rpg2019',
#  '0',
#  '_todaydate',
#  '20200817',
#  'server_date',
#  '08',
#  '17',
#  '20',
#  '33',
#  '1',
#  '45',
#  '18',
#  '2020',
#  '35',
#  'server_date_iso',
#  '2020',
#  '08',
#  '17t16',
#  '45',
#  '35z',
#  'server_date_timestamp',
#  '1597682735',
#  'server_date_split',
#  'server_date',
#  'split',
#  'server_hour',
#  'server_date_split',
#  '6',
#  '1',
#  'uuid',
#  'firstpubmobile',
#  'sezione',
#  'home',
#  'sottosezione',
#  'default',
#  'section_lev1',
#  'home',
#  'section_lev2',
#  'default',
#  'channel_page_title',
#  'tipologia',
#  'home',
#  'subtype',
#  'competizione',
#  'firstpub',
#  'firma',
#  'antiadblocktype',
#  '2',
#  'isadblockenable',
#  '0',
#  'loginlogger',
#  'window',
#  '_logger',
#  '_logger',
#  'login',
#  'window',
#  'console',
#  'ishotjarenabled',
#  'falsevar',
#  'cpmt_checkfunction',
#  'function',
#  'n',
#  'var',
#  'e',
#  'undefined',
#  'try',
#  'n',
#  'typeof',
#  'n',
#  'e',
#  '5334',
#  'n',
#  'catch',
#  'c',
#  'n',
#  'typeof',
#  'n',
#  'e',
#  'null',
#  'n',
#  'var',
#  'c',
#  'new',
#  'regexp',
#  'cpmt_xa',
#  'n',
#  'return',
#  'null',
#  'document',
#  'cookie',
#  'match',
#  'c',
#  '1',
#  'document',
#  'cookie',
#  'indexof',
#  '__ric',
#  'undefined',
#  'typeof',
#  'privacyok',
#  'window',
#  'privacyok',
#  'cpmt_checkfunction',
#  'window',
#  'innerwidthrcsad_listpos',
#  'position1',
#  'left1',
#  'right1',
#  'topleft',
#  'frame1',
#  'rcsad_sitepage',
#  'corriere',
#  'homepage',
#  'hpcorriere',
#  'n',
#  't',
#  'n',
#  'rcsad_disabled',
#  'true',
#  'n',
#  'nvar',
#  'v_chartbeat',
#  'true',
#  'var',
#  'utag_data',
#  'var',
#  'utag_cfg_ovrd',
#  'domain',
#  'components2',
#  'rcsobjects',
#  'path',
#  'https',
#  'components2',
#  'rcsobjects',
#  'rcs_tealium',
#  'v1',
#  'distro',
#  'corriere',
#  'preprod',
#  'env',
#  'preprod',
#  'var',
#  'config',
#  'getflavor',
#  'function',
#  'return',
#  'desktop',
#  'components',
#  'type',
#  'ext',
#  'src',
#  'https',
#  'components2',
#  'rcsobjects',
#  'rcs_tealium',
#  'v1',
#  'distro',
#  'corriere',
#  'preprod',
#  'utag',
#  'sync',
#  'js',
#  'v',
#  '08ca22378728aaf3e34665e5c4c423f5',
#  'priority',
#  '1',
#  'type',
#  'ext',
#  'src',
#  'https',
#  'components2',
#  'rcsobjects',
#  'rcs_tealium',
#  'v1',
#  'distro',
#  'corriere',
#  'preprod',
#  'utag',
#  'js',
#  'v',
#  '6fda832769c2dc71bb27f3654f528be8',
#  'priority',
#  '2',
#  'type',
#  'ext',
#  'src',
#  'apw',
#  'js',
#  'v',
#  '4',
#  'priority',
#  '1',
#  'type',
#  'ext',
#  'src',
#  'apw',
#  'js',
#  'v',
#  '4',
#  'f',
#  'mod',
#  'priority',
#  '2',
#  'type',
#  'module',
#  'src',
#  'legacy',
#  'jquery',
#  'priority',
#  '1',
#  'events',
#  'target',
#  'document',
#  'eventname',
#  'domcontentloaded',
#  'type',
#  'module',
#  'src',
#  'global',
#  'desktop',
#  'default',
#  'priority',
#  '2',
#  'events',
#  'target',
#  'document',
#  'eventname',
#  'domcontentloaded',
#  'type',
#  'ext',
#  'src',
#  'https',
#  'components2',
#  'corriereobjects',
#  'rcs_cor_userauth',
#  'v1',
#  'index',
#  'min',
#  'js',
#  'v',
#  '6732d569e8edfa99e3a96ebd4bbebb35',
#  'priority',
#  '5',
#  'legacy',
#  'true',
#  'flavors',
#  'desktop',
#  'tablet',
#  'events',
#  'target',
#  'window',
#  'eventname',
#  'load',
#  'callback',
#  'function',
#  'const',
#  'component',
#  'new',
#  'rcscoruserauth',
#  'menu',
#  'user',
#  'component',
#  'render',
#  'type',
#  'ext',
#  'src',
#  'https',
#  'components2',
#  'corriereobjects',
#  'rcs_cor_menu',
#  'v3',
#  'index',
#  'min',
#  'js',
#  'v',
#  '70a7c11eb3fbaa77b37aa67e9f31b9ac',
#  'priority',
#  '5',
#  'legacy',
#  'true',
#  'flavors',
#  'desktop',
#  'tablet',
#  'events',
#  'target',
#  'window',
#  'eventname',
#  'load',
#  'callback',
#  'function',
#  'var',
#  'component',
#  'new',
#  'rcscormenu',
#  'currentdevice',
#  'component',
#  'render',
#  'type',
#  'style',
#  'src',
#  'https',
#  'css2',
#  'corriereobjects',
#  'includes2013',
#  'libs',
#  'css',
#  'vendor',
#  'login_com',
#  'css',
#  'priority',
#  '10',
#  'flavors',
#  'desktop',
#  'tablet',
#  'events',
#  'target',
#  'document',
#  'eventname',
#  'rcscoruserauth',
#  'start',
#  'type',
#  'style',
#  'src',
#  'https',
#  'css2',
#  'corriereobjects',
#  'includes2013',
#  'libs',
#  'css',
#  'vendor',
#  'plugins',
#  'jquery',
#  'fancybox',
#  'css',
#  'priority',
#  '10',
#  'flavors',
#  'desktop',
#  'tablet',
#  'events',
#  'target',
#  'document',
#  'eventname',
#  'rcscoruserauth',
#  'start',
#  'type',
#  'ext',
#  'src',
#  'https',
#  'components2',
#  'corriereobjects',
#  'rcs_cor_top',
#  'search',
#  'bar',
#  'v2',
#  'index',
#  'min',
#  'js',
#  'priority',
#  '6',
#  'flavors',
#  'desktop',
#  'tablet',
#  'events',
#  'target',
#  'window',
#  'eventname',
#  'load',
#  'callback',
#  'function',
#  'var',
#  'componentsearch',
#  'new',
#  'rcscortopsearchbar',
#  'componentsearch',
#  'render',
#  'type',
#  'module',
#  'src',
#  'hotjarloader',
#  'priority',
#  '10',
#  'legacy',
#  'true',
#  'events',
#  'target',
#  'window',
#  'eventname',
#  'load',
#  'type',
#  'ext',
#  'src',
#  'https',
#  'js2',
#  'corriereobjects',
#  'includes2013',
#  'libs',
#  'js',
#  'vwo',
#  'js',
#  'priority',
#  '10',
#  'type',
#  'module',
#  'src',
#  'global',
#  'desktop',
#  'home',
#  'priority',
#  '1',
#  'events',
#  'target',
#  'window',
#  'eventname',
#  'load',
#  'type',
#  'module',
#  'src',
#  'menu',
#  'sticky',
#  'home',
#  'priority',
#  '2',
#  'flavors',
#  'desktop',
#  'tablet',
#  'events',
#  'target',
#  'document',
#  'eventname',
#  'domcontentloaded',
#  'type',
#  'module',
#  'src',
#  'sponsorstrip',
#  'onelementspresence',
#  'targets',
#  'bck',
#  'media',
#  'list',
#  'sponsor',
#  'event',
#  'domcontentloaded',
#  'flavors',
#  'desktop',
#  'tablet',
#  'priority',
#  '3',
#  'type',
#  'ext',
#  'src',
#  'https',
#  'imasdk',
#  'googleapis',
#  'com',
#  'js',
#  'sdkloader',
#  'ima3',
#  'js',
#  'flavors',
#  'desktop',
#  'tablet',
#  'priority',
#  '2',
#  'type',
#  'ext',
#  'src',
#  'https',
#  'components2',
#  'corriereobjects',
#  'rcs_most',
#  'viewed',
#  'v1',
#  'index',
#  'min',
#  'js',
#  'v',
#  'b5ab2fc15071edab92338df296a3cb0c',
#  'priority',
#  '30',
#  'flavors',
#  'tablet',
#  'desktop',
#  'events',
#  'target',
#  'document',
#  'eventname',
#  'domcontentloaded',
#  'callback',
#  'function',
#  'var',
#  'component',
#  'new',
#  'rcsmostviewed',
#  'bk_cop_011',
#  'letti',
#  'component',
#  'render',
#  'type',
#  'ext',
#  'src',
#  'https',
#  'components2',
#  'corriereobjects',
#  'rcs_cor_weather',
#  'v2',
#  'index',
#  'min',
#  'js',
#  'priority',
#  '6',
#  'flavors',
#  'desktop',
#  'events',
#  'target',
#  'document',
#  'eventname',
#  'domcontentloaded',
#  'callback',
#  'function',
#  'var',
#  'component',
#  'new',
#  'rcscorweather',
#  'bck',
#  'meteo',
#  'component',
#  'render',
#  'type',
#  'ext',
#  'src',
#  'https',
#  'components2',
#  'corriereobjects',
#  'rcs_mc_widget_fe',
#  'v0',
#  'index',
#  'min',
#  'js',
#  'v',
#  'ff093a5a0219ae2472779871d805e68c',
#  'priority',
#  '6',
#  'onviewport',
#  'target',
#  'matchcenter',
#  'widget',
#  'offset',
#  '100',
#  'type',
#  'style',
#  'src',
#  'https',
#  'components2',
#  'corriereobjects',
#  'rcs_mc_widget_fe',
#  'v0',
#  'main',
#  'css',
#  'v',
#  'cfb340fc62782646d5930a290635dc7d',
#  'priority',
#  '2',
#  'onviewport',
#  'target',
#  'matchcenter',
#  'widget',
#  'offset',
#  '100',
#  'type',
#  'ext',
#  'src',
#  'https',
#  'components2',
#  'corriereobjects',
#  'rcs_cor_exit',
#  'page',
#  'v2',
#  'index',
#  'min',
#  'js',
#  'priority',
#  '20',
#  'flavors',
#  'desktop',
#  'callback',
#  'function',
#  'var',
#  'component',
#  'new',
#  'rcscorexitpage',
#  'component',
#  'render',
#  'type',
#  'ext',
#  'src',
#  'https',
#  'components2',
#  'corriereobjects',
#  'rcs_videoplayer',
#  'v2',
#  'index',
#  'min',
#  'js',
#  'v',
#  '45f7e0549262cc19d851fe9645b120fe',
#  'priority',
#  '3',
#  'callback',
#  'function',
#  'window',
#  'playerfactory',
#  'new',
#  'rcsvideo',
#  'console',
#  'log',
#  'player',
#  'loaded',
#  'type',
#  'ext',
#  'src',
#  'https',
#  'components2',
#  'corriereobjects',
#  'rcs_video',
#  'manager',
#  'v2',
#  'index',
#  'min',
#  'js',
#  'v',
#  '8d7ac8dddd8e39b135855997721f2988',
#  'legacy',
#  'true',
#  'priority',
#  '4',
#  'events',
#  'target',
#  'window',
#  'eventname',
#  'load',
#  'callback',
#  'function',
#  'var',
#  'rcsvideocomponent',
#  'new',
#  'rcsvideomanager',
#  'player',
#  'rcsvideocomponent',
#  'render',
#  'type',
#  'ext',
#  'src',
#  'https',
#  'components',
#  'rcsobjects',
#  'rcs_gallery',
#  'manager',
#  'v2',
#  'index',
#  'min',
#  'js',
#  'v',
#  'fa3ed060820b302a28883f89a339dc6c',
#  'legacy',
#  'true',
#  'events',
#  'target',
#  'document',
#  'eventname',
#  'domcontentloaded',
#  'callback',
#  'function',
#  'var',
#  'rcsgallerymanagercomponent',
#  'new',
#  'rcsgallerymanager',
#  'bck',
#  'carousel',
#  'news',
#  'rcsgallerymanagercomponent',
#  ...]

# %%
#creiamo una lista delle parole presenti nel testo e ne filtriamo un po'

text_list_2 = []
for word in text_list:
    if len(word)> 4 and len(word)< 20 and "/" not in word and "\\" not in word and "(" not in word:
        text_list_2.append(word)

text_list_2 = avoidStopWords(text_list_2, stopwords)

        

#saveYesWords(text_list_2, yes_words)

print(len(list_saved_words))
list_saved_words
# Out:
# sera:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-25-9edbd7cebe69> in <module>
#       6         text_list_2.append(word)
#       7
# ----> 8 text_list_2 = avoidStopWords(text_list_2, stopwords)
#       9
#      10
#
# <ipython-input-16-391fc8b3da31> in avoidStopWords(wordlist, stopwords)
#       4         if word not in stopwords:
#       5             print(word)
# ----> 6             list_saved_words.append(word)
#       7     return list_saved_words
#       8
#
# AttributeError: 'dict' object has no attribute 'append'

# %%
list_saved_words = wordListToFreqDict(list_saved_words)

# %%
# eliminare dal dizionario gli 1

keyword_frequencies_dict = {}

for key, value in list_saved_words.items():
    if value >= 2:
        keyword_frequencies_dict[key] = value

keyword_frequencies_dict
# Out:
# {'b': 2,
#  'n': 6625,
#  't': 13123,
#  'r': 2385,
#  'sera': 4,
#  'news': 4,
#  'e': 179,
#  'ultime': 5,
#  'notizie': 5,
#  'oggi': 7,
#  'da': 43,
#  'italia': 16,
#  'mondo': 3,
#  'http': 5,
#  'type': 33,
#  'corriere': 25,
#  'logo': 2,
#  'url': 13,
#  'https': 30,
#  'corriereobjects': 17,
#  'includes2013': 14,
#  'libs': 14,
#  'css': 16,
#  'svg': 5,
#  'width': 2,
#  '400': 2,
#  'height': 2,
#  '80': 2,
#  'www': 4,
#  'facebook': 3,
#  'com': 7,
#  'twitter': 5,
#  'shtml': 2,
#  'contactpoint': 2,
#  'privacy': 3,
#  'var': 22,
#  'desktop': 17,
#  '0': 13,
#  'server_date': 2,
#  '08': 3,
#  '17': 4,
#  '20': 5,
#  '33': 2,
#  '1': 28,
#  '45': 2,
#  '18': 3,
#  '2020': 15,
#  'server_date_split': 2,
#  '6': 6,
#  'sezione': 2,
#  'home': 8,
#  'default': 4,
#  '2': 8,
#  'window': 23,
#  '_logger': 2,
#  'login': 3,
#  'console': 3,
#  'cpmt_checkfunction': 2,
#  'function': 46,
#  'undefined': 4,
#  'try': 2,
#  'typeof': 6,
#  'catch': 3,
#  'c': 21,
#  'null': 2,
#  'new': 17,
#  'return': 5,
#  'document': 23,
#  'cookie': 4,
#  'privacyok': 4,
#  'true': 8,
#  'v_chartbeat': 2,
#  'utag_data': 3,
#  'utag_cfg_ovrd': 2,
#  'domain': 3,
#  'components2': 15,
#  'rcsobjects': 5,
#  'rcs_tealium': 3,
#  'v1': 6,
#  'distro': 3,
#  'preprod': 4,
#  'config': 5,
#  'getflavor': 2,
#  'components': 2,
#  'ext': 19,
#  'src': 31,
#  'utag': 4,
#  'js': 25,
#  'v': 16,
#  'priority': 27,
#  'apw': 2,
#  '4': 12,
#  'module': 6,
#  'legacy': 8,
#  'jquery': 2,
#  'events': 16,
#  'target': 18,
#  'eventname': 16,
#  'domcontentloaded': 9,
#  'global': 2,
#  'index': 11,
#  'min': 11,
#  '5': 11,
#  'flavors': 12,
#  'tablet': 10,
#  'load': 10,
#  'callback': 11,
#  'const': 2,
#  'component': 15,
#  'rcscoruserauth': 3,
#  'menu': 2,
#  'render': 9,
#  'currentdevice': 3,
#  'style': 7,
#  'css2': 2,
#  'vendor': 2,
#  '10': 11,
#  'start': 2,
#  'v2': 6,
#  'componentsearch': 3,
#  'js2': 2,
#  'sticky': 2,
#  'bck': 5,
#  'media': 3,
#  'list': 2,
#  '3': 9,
#  '30': 4,
#  'letti': 4,
#  'meteo': 2,
#  'rcs_mc_widget_fe': 2,
#  'v0': 2,
#  'onviewport': 2,
#  'matchcenter': 2,
#  'widget': 2,
#  'offset': 2,
#  '100': 6,
#  'main': 3,
#  'log': 2,
#  'player': 2,
#  'manager': 2,
#  'rcsvideocomponent': 3,
#  'rcsgallerymanagercomponent': 2,
#  'volocom': 2,
#  'outbrain': 3,
#  '8': 5,
#  'rcsantiadblockercomponent': 2,
#  'addeventlistener': 8,
#  'rcsorchestrator': 4,
#  'riportare': 2,
#  'nel': 15,
#  'rcs': 5,
#  'video': 17,
#  'font': 2,
#  'face': 2,
#  'tfont': 6,
#  'family': 2,
#  'normal': 4,
#  'weight': 2,
#  'tsrc': 4,
#  'fonts': 10,
#  'brera': 10,
#  'brecnbd': 5,
#  'webfont': 10,
#  'eot': 4,
#  'iefix': 2,
#  'format': 8,
#  'embedded': 2,
#  'opentype': 2,
#  'woff': 4,
#  'ttf': 2,
#  'truetype': 2,
#  'brecnrg': 5,
#  'provvisorio': 6,
#  'mf': 2,
#  'p': 4,
#  'hour': 7,
#  'visibility': 3,
#  'html': 4,
#  'response': 2,
#  'text': 3,
#  'tvar': 4,
#  'parser': 3,
#  'doc': 2,
#  'queryselector': 4,
#  'span': 4,
#  'tdocument': 3,
#  'visible': 2,
#  'err': 2,
#  'twindow': 2,
#  'eventdfpready': 12,
#  'googletag': 20,
#  'cmd': 10,
#  'push': 14,
#  'display': 11,
#  'rcsad_position1': 2,
#  'o': 27,
#  'sezioni': 2,
#  'nle': 21,
#  'lettere': 6,
#  'al': 39,
#  'direttore': 4,
#  'il': 109,
#  'caff': 2,
#  'egrave': 6,
#  'gramellini': 2,
#  'lo': 14,
#  'italians': 2,
#  'beppe': 4,
#  'severgnini': 2,
#  'nil': 34,
#  'padiglione': 2,
#  'ultimo': 6,
#  'banco': 2,
#  'd': 17,
#  'rsquo': 132,
#  'avenia': 2,
#  'rifare': 2,
#  'facce': 2,
#  'nuove': 10,
#  'chinese': 2,
#  'editorials': 2,
#  'version': 2,
#  'nvideo': 4,
#  'ninchieste': 2,
#  'ncosa': 2,
#  'daily': 2,
#  'nelezioni': 12,
#  'nregionali': 2,
#  '2019': 11,
#  'ncomunali': 2,
#  '2018': 9,
#  '2017': 11,
#  'regionali': 4,
#  'sicilia': 2,
#  'l': 50,
#  'autonomia': 3,
#  'comunali': 2,
#  'nprimarie': 2,
#  'pd': 2,
#  '2016': 4,
#  'nla': 33,
#  'crisi': 4,
#  'governo': 12,
#  'crollo': 4,
#  'ponte': 4,
#  'morandi': 2,
#  'genova': 2,
#  'nroyal': 2,
#  '50': 5,
#  'anni': 16,
#  'dopo': 13,
#  'strage': 2,
#  'usa': 4,
#  'giorni': 13,
#  'europa': 4,
#  'spagna': 3,
#  'ngermania': 2,
#  'unito': 2,
#  'neconomia': 2,
#  'nfinanza': 2,
#  'fondi': 3,
#  'nguide': 4,
#  'vostre': 4,
#  'domande': 3,
#  'nuvola': 6,
#  'lavoro': 9,
#  'business': 2,
#  'storie': 5,
#  'la': 106,
#  'nl': 16,
#  'economia': 2,
#  'futuro': 4,
#  'genera': 2,
#  'ninnovazione': 2,
#  'che': 52,
#  'investe': 3,
#  'nmoda': 3,
#  'dirette': 4,
#  'nserie': 3,
#  'ncalendario': 5,
#  'risultati': 5,
#  'nclassifiche': 3,
#  'nmarcatori': 2,
#  'league': 5,
#  'neuropa': 2,
#  'nclassifica': 2,
#  'naltri': 3,
#  'sport': 6,
#  'lettura': 2,
#  'data': 2,
#  'agrave': 12,
#  'online': 6,
#  'nblog': 4,
#  'nspeciale': 7,
#  'nmaturita': 2,
#  'parola': 4,
#  'settimana': 7,
#  'nfestival': 3,
#  'nedizione': 14,
#  'cinema': 6,
#  'racconto': 2,
#  'nsalute': 2,
#  'tempo': 9,
#  'salute': 8,
#  'dolce': 2,
#  'vita': 5,
#  'ne': 4,
#  'nmalattie': 2,
#  'nricette': 2,
#  'ncome': 2,
#  'conservare': 2,
#  'cibi': 2,
#  'ni': 21,
#  'pronto': 2,
#  'dubbi': 4,
#  'mamma': 4,
#  'pap': 4,
#  'cosa': 2,
#  'sono': 17,
#  'centri': 4,
#  'cura': 3,
#  'trovare': 2,
#  'si': 29,
#  'sperimentano': 2,
#  'nuovi': 8,
#  'psiconcologia': 2,
#  'nforum': 2,
#  'esperto': 4,
#  'risponde': 4,
#  'sangue': 3,
#  'acqua': 10,
#  'nanimali': 2,
#  'ed': 4,
#  'gatti': 4,
#  'amp': 10,
#  'salvare': 5,
#  'veterinario': 2,
#  'ntecnologia': 2,
#  'scelta': 2,
#  'facciamo': 2,
#  'google': 2,
#  'world': 2,
#  'nvideogiochi': 2,
#  'digitali': 3,
#  'tv': 3,
#  'blog': 4,
#  'digitale': 7,
#  'tech': 3,
#  'gradi': 2,
#  'ora': 12,
#  'legale': 2,
#  'valley': 7,
#  'nmotori': 6,
#  'motori': 2,
#  'nsalone': 3,
#  'parigi': 6,
#  'guido': 4,
#  'cane': 2,
#  'heavy': 2,
#  'rider': 4,
#  'le': 66,
#  'dello': 14,
#  'nin': 6,
#  'viaggio': 10,
#  'bello': 4,
#  'dell': 18,
#  'birra': 4,
#  'cocktails': 2,
#  'npersonaggi': 2,
#  'regola': 2,
#  'delle': 32,
#  'donne': 8,
#  'segni': 2,
#  'cambiamento': 2,
#  'nsfilate': 2,
#  'donna': 5,
#  'uomo': 3,
#  'libri': 2,
#  'locali': 4,
#  'abbonamentidigital': 2,
#  'academycruciverba': 2,
#  'corriereattiva': 2,
#  'storecomunilotterie': 2,
#  'abbonatilo': 2,
#  'stato': 7,
#  'tuo': 4,
#  'abbonamento': 2,
#  'verificare': 2,
#  'clicca': 6,
#  'qui': 4,
#  'carta': 4,
#  'credito': 7,
#  'aggiornare': 4,
#  'important': 2,
#  'mio': 2,
#  'corrierenewsletter': 2,
#  'gestisci': 2,
#  'profilo': 2,
#  'logoutcerca': 2,
#  'sitoin': 2,
#  'viagginel': 2,
#  'dizionario': 2,
#  'rcsad_left1': 2,
#  'luned': 2,
#  'xec': 17,
#  'agosto': 18,
#  'aggiornato': 4,
#  'alle': 4,
#  'nbsp': 34,
#  '36': 2,
#  'milanomilano': 2,
#  'lorenteggiomilano': 2,
#  'baggiomilano': 2,
#  'rcsad_right1': 2,
#  'rcsad_topleft': 2,
#  'caldi': 2,
#  'coronavirus': 4,
#  'euro': 4,
#  'ordinanza': 3,
#  'ndiscoteche': 3,
#  'chiuse': 3,
#  'gestori': 2,
#  'ricorrono': 2,
#  'ecco': 11,
#  'regole': 7,
#  'testo': 2,
#  'ndi': 106,
#  'claudia': 4,
#  'voltattorni': 3,
#  'decisione': 4,
#  'xe8': 47,
#  'stata': 6,
#  'presa': 2,
#  'durante': 6,
#  'riunione': 2,
#  'direttivo': 2,
#  'nazionale': 4,
#  'quello': 4,
#  'bloccare': 2,
#  'gli': 12,
#  'effetti': 2,
#  'ministero': 6,
#  'ncoronavirus': 4,
#  'stop': 3,
#  'ballo': 4,
#  'tutta': 2,
#  'stretta': 2,
#  'sulle': 6,
#  'mascherine': 8,
#  'nei': 3,
#  'luoghi': 4,
#  'movida': 4,
#  'limitiamo': 2,
#  'diritti': 4,
#  'solo': 9,
#  'se': 13,
#  'non': 31,
#  'riesce': 2,
#  'curare': 2,
#  'xbb': 83,
#  'giuseppe': 8,
#  'alberto': 4,
#  'rabbia': 4,
#  'linus': 2,
#  'xabperch': 2,
#  'xe9': 9,
#  'avete': 4,
#  'fatte': 4,
#  'aprire': 2,
#  'eravate': 4,
#  'ubriachi': 2,
#  'discoteche': 6,
#  'patron': 2,
#  'muretto': 2,
#  'nemmeno': 2,
#  'contagio': 5,
#  'mauro': 4,
#  'nporto': 2,
#  'giorgio': 4,
#  'malta': 2,
#  'ma': 15,
#  'aspetta': 2,
#  'esito': 2,
#  'tampone': 4,
#  'positivo': 6,
#  'una': 28,
#  'party': 2,
#  'sulla': 18,
#  'spiaggia': 7,
#  'test': 5,
#  'persone': 6,
#  'laura': 6,
#  'martellini': 2,
#  'appello': 4,
#  'azienda': 3,
#  'sanitaria': 3,
#  'locale': 3,
#  'venite': 2,
#  'fare': 4,
#  'nroma': 2,
#  'giovani': 4,
#  'contagiati': 4,
#  'festa': 2,
#  'porto': 2,
#  'xabc': 2,
#  'anche': 22,
#  'clarida': 2,
#  'salvatori': 4,
#  'aeroporto': 2,
#  'succede': 2,
#  'volato': 2,
#  'passeggero': 2,
#  'leonard': 4,
#  'berberi': 2,
#  'primi': 12,
#  'essere': 4,
#  'contattati': 2,
#  'saranno': 4,
#  'quelli': 8,
#  'seduti': 2,
#  'fianco': 2,
#  'soggetto': 2,
#  'infetto': 2,
#  'nelle': 8,
#  'davanti': 2,
#  'na': 2,
#  'fiumicino': 2,
#  'quattro': 8,
#  'positivi': 3,
#  'mila': 7,
#  'rapidi': 2,
#  'dal': 9,
#  'plotino': 2,
#  'bollettino': 3,
#  'casi': 5,
#  'ore': 2,
#  'decessi': 2,
#  'aumentano': 2,
#  'nessun': 4,
#  'morto': 3,
#  'pandemia': 9,
#  'aggiornati': 2,
#  'mappa': 2,
#  'ntutti': 2,
#  'bollettini': 2,
#  'protezione': 2,
#  'redazione': 29,
#  'proposta': 2,
#  'presidi': 5,
#  'ogni': 2,
#  'scuola': 10,
#  'ci': 5,
#  'sospetti': 4,
#  'dirigenti': 2,
#  'istituto': 2,
#  'chiedono': 2,
#  'rivedere': 2,
#  'norma': 2,
#  'sicurezza': 2,
#  'negli': 6,
#  'ambienti': 2,
#  'presidente': 14,
#  'giannelli': 2,
#  'calendario': 2,
#  'consegna': 2,
#  'banchi': 3,
#  'nritorno': 3,
#  'classe': 3,
#  'senza': 16,
#  'mascherina': 9,
#  'diverse': 2,
#  'zona': 3,
#  'gianna': 6,
#  'fregonara': 3,
#  'nviviana': 2,
#  'parisi': 8,
#  'testimone': 3,
#  'incidente': 7,
#  'gioele': 9,
#  'era': 9,
#  'salvo': 6,
#  'sul': 6,
#  'caso': 2,
#  'ricostruzione': 4,
#  'presente': 2,
#  'impatto': 4,
#  'procuratore': 2,
#  'angelo': 4,
#  'indaga': 2,
#  'morte': 4,
#  'dj': 2,
#  'viviana': 8,
#  'scomparsa': 2,
#  'figlio': 8,
#  'ripercorso': 4,
#  'passo': 10,
#  'nino': 2,
#  'luca': 5,
#  'bugia': 3,
#  'marito': 5,
#  'tutti': 16,
#  'punti': 2,
#  'andrea': 6,
#  'wuhan': 2,
#  'ha': 32,
#  'pi': 25,
#  'xf9': 24,
#  'paura': 4,
#  'migliaia': 4,
#  'piscina': 3,
#  'immagini': 4,
#  'cina': 4,
#  'destano': 2,
#  'festival': 2,
#  'musica': 3,
#  'citt': 8,
#  'xe0': 41,
#  'simbolo': 2,
#  'approva': 2,
#  'suo': 6,
#  'primo': 6,
#  'ncos': 3,
#  'provincia': 4,
#  'fatto': 8,
#  'xabculla': 2,
#  'peste': 4,
#  'sars': 2,
#  'sandro': 4,
#  'modeo': 2,
#  'consiglio': 4,
#  'superiore': 4,
#  'xc0': 2,
#  'contagi': 2,
#  'arrivano': 2,
#  'dai': 6,
#  'turisti': 4,
#  '25': 2,
#  '40': 2,
#  'migranti': 2,
#  'margherita': 2,
#  'comitato': 2,
#  'tecnico': 2,
#  'xabla': 2,
#  'chiusura': 7,
#  'pronti': 4,
#  'ad': 5,
#  'altre': 6,
#  'restrizioni': 3,
#  'ncovid': 2,
#  'bimba': 2,
#  'intubata': 2,
#  'sindrome': 2,
#  'giovanni': 4,
#  'figlia': 6,
#  'cossiga': 3,
#  'padre': 7,
#  'notte': 2,
#  'io': 5,
#  'marzio': 2,
#  'maria': 8,
#  'dolore': 4,
#  'xf2': 7,
#  'guerra': 6,
#  'golfo': 2,
#  'mi': 5,
#  'prendere': 2,
#  'ex': 4,
#  'sento': 2,
#  'colpa': 2,
#  'sua': 8,
#  'nmotogp': 2,
#  'dibattito': 2,
#  'nma': 2,
#  'zarco': 2,
#  'colpevole': 2,
#  'tutte': 6,
#  'ragioni': 2,
#  'condanna': 2,
#  'unanime': 2,
#  'foto': 11,
#  'paolo': 12,
#  'ndopo': 2,
#  'austria': 3,
#  'infuria': 2,
#  'polemica': 2,
#  'rossi': 9,
#  'morbidelli': 2,
#  'pedrosa': 2,
#  'michele': 4,
#  'pirro': 2,
#  'ducati': 2,
#  'assolve': 2,
#  'francese': 3,
#  'errore': 2,
#  'poteva': 2,
#  'direzione': 4,
#  'comunque': 2,
#  'valentino': 6,
#  'ricordo': 2,
#  'dentro': 2,
#  'gioco': 7,
#  'volano': 2,
#  'moto': 2,
#  'gran': 2,
#  'premio': 4,
#  'miracolo': 2,
#  'superbagnino': 2,
#  'quarto': 2,
#  'salvato': 2,
#  'bambino': 2,
#  'svenuto': 2,
#  'eleonora': 2,
#  'avvenuto': 2,
#  'domenica': 4,
#  'ginestra': 2,
#  'xabl': 2,
#  'dato': 2,
#  'braccio': 2,
#  'ormai': 2,
#  'respirava': 2,
#  'poi': 4,
#  'accasciato': 2,
#  'terra': 4,
#  'lui': 3,
#  'xc8': 4,
#  'quindicenne': 2,
#  'travolto': 2,
#  'auto': 7,
#  'pirata': 4,
#  'discoteca': 5,
#  'ferragosto': 3,
#  'nera': 4,
#  'su': 16,
#  'motorino': 2,
#  'amico': 3,
#  '19': 5,
#  'presentato': 2,
#  'carabinieri': 2,
#  'ragazza': 4,
#  '15': 2,
#  'travolta': 2,
#  'uccisa': 2,
#  'picchia': 2,
#  'stava': 2,
#  'curando': 2,
#  'ragazzo': 3,
#  'entrare': 2,
#  'aggredito': 2,
#  'turista': 2,
#  '32enne': 2,
#  'romano': 2,
#  'mattino': 2,
#  'mentre': 4,
#  'prestava': 2,
#  'prime': 4,
#  'sentito': 2,
#  'male': 2,
#  'fenomeno': 3,
#  'numero': 2,
#  'chiuso': 3,
#  'obbligo': 2,
#  'lotta': 2,
#  'sindaci': 2,
#  'contro': 22,
#  'claudio': 2,
#  'frate': 2,
#  'accessi': 2,
#  'prenotazione': 2,
#  'alcune': 2,
#  'divieto': 4,
#  'sedersi': 4,
#  'sui': 3,
#  'gradini': 2,
#  'campania': 2,
#  'ovunque': 2,
#  'alla': 15,
#  'vendita': 6,
#  'alcolici': 2,
#  '21': 2,
#  'uniti': 2,
#  'nnella': 2,
#  'death': 6,
#  '54': 3,
#  'potrebbe': 2,
#  'temperatura': 2,
#  'alta': 6,
#  'mai': 6,
#  'raggiunta': 2,
#  'francesco': 4,
#  'tortora': 2,
#  'picco': 2,
#  'volte': 5,
#  'nella': 22,
#  'storia': 14,
#  'state': 2,
#  'rilevate': 2,
#  'temperature': 2,
#  'successo': 4,
#  'inizio': 3,
#  'novecento': 3,
#  'strumenti': 2,
#  'meno': 4,
#  'attendibili': 2,
#  'ntemperatura': 2,
#  'record': 5,
#  'xb0': 2,
#  'forse': 4,
#  'registrata': 2,
#  'tragitto': 2,
#  'mattina': 2,
#  'sfiorato': 2,
#  'terribile': 2,
#  'rifiuta': 4,
#  'mano': 3,
#  'donald': 3,
#  'trump': 5,
#  'altra': 2,
#  'volta': 5,
#  'lady': 2,
#  'scacciato': 2,
#  'rimedio': 2,
#  'chi': 6,
#  'inventato': 4,
#  'xabspara': 2,
#  'praja': 2,
#  'vocalist': 2,
#  'xabnon': 2,
#  'quanto': 4,
#  'potrete': 2,
#  'cessione': 4,
#  'unicredit': 2,
#  'banche': 6,
#  'decreti': 2,
#  'circolari': 2,
#  'hanno': 6,
#  'delineato': 2,
#  'effettuare': 4,
#  'fiscale': 3,
#  'relativo': 2,
#  'ai': 8,
#  'lavori': 2,
#  'ristrutturazione': 4,
#  'efficientamento': 2,
#  'energetico': 2,
#  'possibile': 4,
#  'andare': 2,
#  'sportello': 2,
#  'avviare': 2,
#  'mantenimento': 2,
#  'studi': 2,
#  'obbligatorio': 6,
#  'trovarsi': 2,
#  'massimiliano': 2,
#  'jattoni': 2,
#  'dall': 4,
#  'tribunale': 2,
#  'ultima': 3,
#  'istanza': 2,
#  'respinto': 2,
#  'ricorso': 2,
#  'contestava': 2,
#  'corte': 2,
#  'revocare': 2,
#  '30enne': 2,
#  'nsmart': 2,
#  'working': 4,
#  'londra': 4,
#  'xablavorare': 2,
#  'casa': 7,
#  'sempre': 10,
#  'questa': 2,
#  'fine': 7,
#  'ufficio': 6,
#  'paola': 8,
#  'carolis': 4,
#  'covid': 7,
#  'cambiato': 2,
#  'banca': 2,
#  'schroders': 2,
#  'deciso': 4,
#  'sar': 2,
#  'dipendenti': 2,
#  'requisito': 2,
#  'presentarsi': 2,
#  'intanto': 3,
#  'svuotano': 2,
#  'tanti': 3,
#  'palazzi': 2,
#  'anticipa': 2,
#  'anti': 2,
#  'milioni': 10,
#  'prevede': 2,
#  'vettore': 2,
#  'tricolore': 2,
#  'riconosciuti': 2,
#  'fino': 2,
#  'dolomiti': 2,
#  'tutto': 4,
#  'compra': 2,
#  'principia': 2,
#  'biopharma': 2,
#  'miliardi': 2,
#  'dollari': 3,
#  'gruppo': 2,
#  'azioni': 4,
#  'americana': 4,
#  'prezzo': 6,
#  'ciascuna': 2,
#  'opa': 2,
#  'dovrebbe': 2,
#  'iniziare': 2,
#  'levante': 2,
#  'mare': 4,
#  'tuffato': 2,
#  'tornato': 2,
#  'provvedimento': 3,
#  'commesso': 2,
#  'sistema': 6,
#  'postale': 2,
#  'americano': 4,
#  'massimo': 6,
#  'nominato': 2,
#  'fedelissimo': 2,
#  'louis': 2,
#  'dejoy': 2,
#  'capo': 2,
#  'boicottare': 2,
#  'poste': 2,
#  'federali': 2,
#  'impedire': 2,
#  'agli': 2,
#  'elettori': 2,
#  'esprimere': 2,
#  'propria': 2,
#  'voto': 2,
#  'corrispondenza': 2,
#  'smart': 2,
#  'finisce': 2,
#  'gossip': 2,
#  'saremo': 2,
#  'carlotta': 2,
#  'illusioni': 2,
#  'politici': 3,
#  'nrisponde': 2,
#  'luciano': 2,
#  'collana': 2,
#  'xabcorriere': 2,
#  'delitti': 2,
#  'regalo': 2,
#  'volume': 2,
#  'luigi': 3,
#  'francia': 2,
#  'obbligatoria': 2,
#  'aziende': 6,
#  'nsu': 2,
#  'edicola': 2,
#  'super': 5,
#  'fa': 4,
#  'ida': 2,
#  'bozzi': 2,
#  'obiettivi': 2,
#  'comuni': 2,
#  'fanno': 8,
#  'grande': 4,
#  'manovre': 2,
#  'elliott': 2,
#  'perdita': 2,
#  'mario': 4,
#  'friedkin': 3,
#  'offerto': 2,
#  'terzo': 6,
#  'valore': 2,
#  'mercato': 7,
#  'michelangelo': 4,
#  'borrillo': 2,
#  'vedova': 2,
#  'm': 3,
#  'antonio': 14,
#  'missionari': 2,
#  'spagnoli': 4,
#  'diventarono': 2,
#  'profumi': 2,
#  'vicino': 6,
#  'conflittocon': 2,
#  'ruolo': 2,
#  'mire': 2,
#  'paese': 7,
#  'serena': 4,
#  'natale': 2,
#  'incontro': 2,
#  'scambio': 2,
#  'tra': 10,
#  'arabo': 2,
#  'torna': 4,
#  'centro': 6,
#  'degli': 12,
#  'equilibri': 2,
#  'meeting': 4,
#  'prova': 6,
#  'energie': 2,
#  ...}

# %%
#funziona, ma non c'è un metodo più semplice?

sorted_keyword_frequencies_dict = sorted(keyword_frequencies_dict.items(), key=lambda x: x[1], reverse=True)

sorted_keyword_frequencies_dict

# %%
#creare un csv con nome sito e lista delle parole+frequenze
df = pd.DataFrame(data=sorted_keyword_frequencies_dict)
df = df.sort_values(by=[1], ascending=False)
df

# %%
#df.to_csv("prova.csv")

# %%
stopwords
